# %% [markdown]
# # Проект по моделям машинного обучения с учителем (supervised learning) - Методы на основе деревьев
#
#
# ## ЦЕЛЬ: Создать модель предсказания того, уйдёт ли абонент в отток (churn).
#
#
# ## Выполните задания ниже, обозначенные жирным шрифтом!
#
# ## Часть 0: Импортируем библиотеки и загружаем данные
#
# **Задание: Запустите уже готовые ячейки ниже, чтобы импортировать библиотеки и загрузить данные из файла в датафрейм. Файл называется "Telco-Customer-Churn.csv"**

# %%
# Запустите эти ячейки для начала выполнения проекта!
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/invet/Downloads/Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Часть 1: Общие характеристики данных
#
# **Задание: С помощью метода .info() проверьте типы данных для колонок, а также есть ли отсутствующие значения в Вашем датафрейме.**

# %%
# Напишите Ваш код в этой ячейке
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# **Задание: Выведите статистические метрики для числовых колонок с помощью .describe(). Вы увидите, что большинство колонок являются категориальными, поэтому Вам позднее нужно будет создать для них дамми-переменные.**

# %%
# Напишите Ваш код в этой ячейке
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# # Часть 2:  Исследование данных (Exploratory Data Analysis)
#
# ## Исследование признаков
#
# **Задание: Проверьте, что в этих данных нет отсутствующих значений - для этого выведите количество значений NaN отдельно для каждой колонки.**

# %%
# Напишите Ваш код в этой ячейке
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# **Задание: Постройте график CountPlot для проверки сбалансированности значений колонки с классами (Churn).**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns

sns.countplot(data=df, x='Churn')
plt.show()

# %% [markdown]
# **Задание: Исследуйте распределение колонки TotalCharges по различным категориям Churn с помощью графика Box Plot или Violin Plot.**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns

sns.boxplot(data=df, x='Churn', y='TotalCharges')
plt.show()

# %% [markdown]
# <img src='fig2.png' >

# %% [markdown]
# **Задание: Постройте график boxplot с распределением колонки TotalCharges для различных типов контрактов, а также добавьте раскраску цветами по колонке Churn.**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns

sns.boxplot(data=df, x='Contract', y='TotalCharges', hue='Churn')
plt.show()

# %% [markdown]
# <img src='fig3.png' >

# %% [markdown]
# **Задание: Постройте график barplot с корреляции указанных ниже признаков с целевой переменной. Обратите внимание, что для категориальных признаков сначала нужно сконвертировать их в дамми-переменные, потому что корреляция вычисляется только для числовых колонок.**
#
#     ['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines',
#      'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
#
# ***Приведен список признаков, чтобы не проверять все признаки. Дело в том, что некоторые признаки имеют слишком много уникальных значений для такого анализа, например колонка customerID.***

# %%
for feature, corr_value in correlation.iteritems():
    print(f"{feature.ljust(40)} {corr_value:.6f}")
# Out:
# SeniorCitizen                            0.150541
# gender_Female                            0.008545
# gender_Male                              -0.008545
# Partner_No                               0.149982
# Partner_Yes                              -0.149982
# Dependents_No                            0.163128
# Dependents_Yes                           -0.163128
# PhoneService_No                          -0.011691
# PhoneService_Yes                         0.011691
# MultipleLines_No                         -0.032654
# MultipleLines_No phone service           -0.011691
# MultipleLines_Yes                        0.040033
# OnlineSecurity_No                        0.342235
# OnlineSecurity_No internet service       -0.227578
# OnlineSecurity_Yes                       -0.171270
# OnlineBackup_No                          0.267595
# OnlineBackup_No internet service         -0.227578
# OnlineBackup_Yes                         -0.082307
# DeviceProtection_No                      0.252056
# DeviceProtection_No internet service     -0.227578
# DeviceProtection_Yes                     -0.066193
# TechSupport_No                           0.336877
# TechSupport_No internet service          -0.227578
# TechSupport_Yes                          -0.164716
# InternetService_DSL                      -0.124141
# InternetService_Fiber optic              0.307463
# InternetService_No                       -0.227578
# StreamingTV_No                           0.128435
# StreamingTV_No internet service          -0.227578
# StreamingTV_Yes                          0.063254
# StreamingMovies_No                       0.130920
# StreamingMovies_No internet service      -0.227578
# StreamingMovies_Yes                      0.060860
# Contract_Month-to-month                  0.404565
# Contract_One year                        -0.178225
# Contract_Two year                        -0.301552
# PaperlessBilling_No                      -0.191454
# PaperlessBilling_Yes                     0.191454
# PaymentMethod_Bank transfer (automatic)  -0.118136
# PaymentMethod_Credit card (automatic)    -0.134687
# PaymentMethod_Electronic check           0.301455
# PaymentMethod_Mailed check               -0.090773
# Churn_No                                 -1.000000

# %% [markdown]
# <img src='figbar.png'>

# %% [markdown]
# ---
# ---
#
# # Часть 3: Анализ оттока
#
# **В этих заданиях мы выполним сегментацию абонентов на основе колонки tenure, создавая "когорты" и выполняя сравнение данных между различными когортами.**

# %% [markdown]
# **Задание: Перечислите 3 типа контракта (колонка Contract).**

# %%
# Напишите Ваш код в этой ячейке
contract_types = df['Contract'].unique()
contract_types
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# **Задание: Создайте гистограмму с распределением значений колонки tenure - это количество месяцев, сколько времени человек является (или являлся) абонентом компании.**

# %%
# Напишите Ваш код в этой ячейке
plt.hist(df['tenure'], bins=30, edgecolor='black')

plt.xlabel('Tenure')
plt.ylabel('Count')
plt.title('Distribution of Tenure')

plt.show()

# %% [markdown]
# <img src="fig5.png">

# %% [markdown]
# **Задание: Постройте гистограммы для колонки tenure, разбивая данные по двум колонкам - Churn и Contract. Посмотрите документацию по seaborn или блокноты для раздела про seaborn, чтобы вспомнить, как это делается.**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns
import matplotlib.pyplot as plt

# Настройка стиля графиков seaborn
sns.set(style="darkgrid")

# Построение гистограмм
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', bins=30, edgecolor='black', alpha=0.7)
plt.title('Distribution of Tenure by Churn')
plt.xlabel('Tenure')
plt.ylabel('Count')

# Создание отдельных графиков для каждого типа контракта
g = sns.FacetGrid(df, col='Contract', hue='Churn', col_wrap=3, height=4)
g.map(sns.histplot, 'tenure', bins=30, edgecolor='black', alpha=0.7)
g.set_titles("{col_name}")
g.set_axis_labels("Tenure", "Count")
g.add_legend()

# Отображение графиков
plt.show()

# %% [markdown]
# <img src="fig6.png">

# %% [markdown]
# **Задание: Постройте график scatterplot для колонок Total Charges и Monthly Charges, раскрашивая график цветами по колонке Churn.**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns
import matplotlib.pyplot as plt

# Настройка стиля графиков seaborn
sns.set(style="darkgrid")

# Построение scatterplot
sns.scatterplot(data=df, x='TotalCharges', y='MonthlyCharges', hue='Churn')

# Настройка осей и заголовка графика
plt.xlabel('Total Charges')
plt.ylabel('Monthly Charges')
plt.title('Scatterplot of Total Charges vs Monthly Charges')

# Отображение графика
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

selected_cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
                 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                 'TechSupport', 'InternetService', 'StreamingTV', 'StreamingMovies',
                 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']
df_selected = df[selected_cols]

df_dummies = pd.get_dummies(df_selected)

correlation = df_dummies.corr()['Churn_Yes']

correlation = correlation.drop('Churn_Yes')

plt.figure(figsize=(12, 6))
sns.barplot(x=correlation.values, y=correlation.index, orient='h')

plt.xlabel('Correlation')
plt.ylabel('Features')
plt.title('Correlation with Churn')

plt.show()


for feature, corr_value in correlation.iteritems():
    print(f"{feature.ljust(40)} {corr_value:.6f}")

<img src='figbar.png'>

---
---

# Часть 3: Анализ оттока

**В этих заданиях мы выполним сегментацию абонентов на основе колонки tenure, создавая "когорты" и выполняя сравнение данных между различными когортами.**

**Задание: Перечислите 3 типа контракта (колонка Contract).**

# Напишите Ваш код в этой ячейке
contract_types = df['Contract'].unique()
contract_types


**Задание: Создайте гистограмму с распределением значений колонки tenure - это количество месяцев, сколько времени человек является (или являлся) абонентом компании.**

# Напишите Ваш код в этой ячейке
plt.hist(df['tenure'], bins=30, edgecolor='black')

plt.xlabel('Tenure')
plt.ylabel('Count')
plt.title('Distribution of Tenure')

plt.show()


<img src="fig5.png">

**Задание: Постройте гистограммы для колонки tenure, разбивая данные по двум колонкам - Churn и Contract. Посмотрите документацию по seaborn или блокноты для раздела про seaborn, чтобы вспомнить, как это делается.**

# Напишите Ваш код в этой ячейке
import seaborn as sns
import matplotlib.pyplot as plt

# Настройка стиля графиков seaborn
sns.set(style="darkgrid")

# Построение гистограмм
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', bins=30, edgecolor='black', alpha=0.7)
plt.title('Distribution of Tenure by Churn')
plt.xlabel('Tenure')
plt.ylabel('Count')

# Создание отдельных графиков для каждого типа контракта
g = sns.FacetGrid(df, col='Contract', hue='Churn', col_wrap=3, height=4)
g.map(sns.histplot, 'tenure', bins=30, edgecolor='black', alpha=0.7)
g.set_titles("{col_name}")
g.set_axis_labels("Tenure", "Count")
g.add_legend()

# Отображение графиков
plt.show()


<img src="fig6.png">

**Задание: Постройте график scatterplot для колонок Total Charges и Monthly Charges, раскрашивая график цветами по колонке Churn.**

# Напишите Ваш код в этой ячейке
import seaborn as sns
import matplotlib.pyplot as plt

# Настройка стиля графиков seaborn
sns.set(style="darkgrid")

# Построение scatterplot
sns.scatterplot(data=df, x='TotalCharges', y='MonthlyCharges', hue='Churn')

# Настройка осей и заголовка графика
plt.xlabel('Total Charges')
plt.ylabel('Monthly Charges')
plt.title('Scatterplot of Total Charges vs Monthly Charges')

# Отображение графика
plt.show()
import seaborn as sns

# Список признаков для анализа
features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 
            'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
            'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']

# Создание дамми-переменных для категориальных признаков
dummy_df = pd.get_dummies(df[features])

# Добавление целевой переменной Churn в dummy-фрейм данных
dummy_df['SeniorCitizen'] = df['SeniorCitizen']

# Вычисление корреляции между каждым признаком и целевой переменной
correlation = dummy_df.corr()['SeniorCitizen'].drop('SeniorCitizen')  # Исключаем корреляцию с самой собой

# Построение графика barplot с корреляцией
plt.figure(figsize=(12, 6))
sns.barplot(x=correlation.index, y=correlation.values)
plt.xticks(rotation=90)
plt.xlabel('Признаки')
plt.ylabel('Корреляция с SeniorCitizen')
plt.title('Корреляция признаков с SeniorCitizen')
plt.show()

# %%
# Out:
# Contract_Two year                         -0.301552
# StreamingMovies_No internet service       -0.227578
# StreamingTV_No internet service           -0.227578
# TechSupport_No internet service           -0.227578
# DeviceProtection_No internet service      -0.227578
# OnlineBackup_No internet service          -0.227578
# OnlineSecurity_No internet service        -0.227578
# InternetService_No                        -0.227578
# PaperlessBilling_No                       -0.191454
# Contract_One year                         -0.178225
# OnlineSecurity_Yes                        -0.171270
# TechSupport_Yes                           -0.164716
# Dependents_Yes                            -0.163128
# Partner_Yes                               -0.149982
# PaymentMethod_Credit card (automatic)     -0.134687
# InternetService_DSL                       -0.124141
# PaymentMethod_Bank transfer (automatic)   -0.118136
# PaymentMethod_Mailed check                -0.090773
# OnlineBackup_Yes                          -0.082307
# DeviceProtection_Yes                      -0.066193
# MultipleLines_No                          -0.032654
# MultipleLines_No phone service            -0.011691
# PhoneService_No                           -0.011691
# gender_Male                               -0.008545
# gender_Female                              0.008545
# PhoneService_Yes                           0.011691
# MultipleLines_Yes                          0.040033
# StreamingMovies_Yes                        0.060860
# StreamingTV_Yes                            0.063254
# StreamingTV_No                             0.128435
# StreamingMovies_No                         0.130920
# Partner_No                                 0.149982
# SeniorCitizen                              0.150541
# Dependents_No                              0.163128
# PaperlessBilling_Yes                       0.191454
# DeviceProtection_No                        0.252056
# OnlineBackup_No                            0.267595
# PaymentMethod_Electronic check             0.301455
# InternetService_Fiber optic                0.307463
# TechSupport_No                             0.336877
# OnlineSecurity_No                          0.342235
# Contract_Month-to-month                    0.404565
# Name: Churn_Yes, dtype: float64

# %% [markdown]
# <img src='figbar.png'>

# %% [markdown]
# ---
# ---
#
# # Часть 3: Анализ оттока
#
# **В этих заданиях мы выполним сегментацию абонентов на основе колонки tenure, создавая "когорты" и выполняя сравнение данных между различными когортами.**

# %% [markdown]
# **Задание: Перечислите 3 типа контракта (колонка Contract).**

# %%
# Напишите Ваш код в этой ячейке
contract_types = df['Contract'].unique()[:3]
print(contract_types)
# Out:
# ['Month-to-month' 'One year' 'Two year']

# %%
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# **Задание: Создайте гистограмму с распределением значений колонки tenure - это количество месяцев, сколько времени человек является (или являлся) абонентом компании.**

# %%
# Напишите Ваш код в этой ячейке
import matplotlib.pyplot as plt

# Создание гистограммы для колонки "tenure"
plt.hist(df['tenure'], bins='auto', edgecolor='k')
plt.xlabel('Количество месяцев')
plt.ylabel('Частота')
plt.title('Распределение tenure')
plt.show()

# %% [markdown]
# <img src="fig5.png">

# %% [markdown]
# **Задание: Постройте гистограммы для колонки tenure, разбивая данные по двум колонкам - Churn и Contract. Посмотрите документацию по seaborn или блокноты для раздела про seaborn, чтобы вспомнить, как это делается.**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns

# Построение гистограммы с разбивкой по колонкам "Churn" и "Contract"
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', kde=True)
plt.xlabel('Количество месяцев')
plt.ylabel('Частота')
plt.title('Распределение tenure с разбивкой по Churn и Contract')
plt.legend(title='Churn')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# <img src="fig6.png">

# %% [markdown]
# **Задание: Постройте график scatterplot для колонок Total Charges и Monthly Charges, раскрашивая график цветами по колонке Churn.**

# %%
# Напишите Ваш код в этой ячейке
import seaborn as sns

# Построение scatterplot с раскраской по колонке "Churn"
sns.scatterplot(data=df, x='TotalCharges', y='MonthlyCharges', hue='Churn')
plt.xlabel('Total Charges')
plt.ylabel('Monthly Charges')
plt.show()

# %% [markdown]
# <img src='fig7.png'>

# %% [markdown]
# ### Создание когорт (сегментов) по колонке Tenure
#
# **Для начала поместим различные значения tenure (1 месяц, 2 месяца, 3 месяца и так далее) в отдельные когорты (сегменты).**
#
# **Задание: Для каждого уникального значения колонки tenure в качестве когорты, вычислите процент оттока (churn rate) - это количество тех людей, кто ушёл в отток в когорте, как процент от общего количества людей в данной когорте. Вычислите такой процент отдельно для каждой когорты. Например, для когорты с tenure = "1 месяц" должен получиться процент оттока 61.99%. В итоге у Вас должны получиться когорты от 1 до 72 месяцев, и с увеличением количества месяцев уровень оттока должен снижаться. Это разумно, потому что чем дольше человек пользуется услугами компании, тем вероятнее то, что его/её всё устраивает, и он/она продолжит пользоваться этими услугами.**

# %%
# Напишите Ваш код в этой ячейке
# Преобразование колонки "Churn" в числовой формат
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# Создание когорт на основе уникальных значений колонки "tenure"
cohorts = df.groupby('tenure')['Churn'].mean() * 100

# Вывод процента оттока (churn rate) для каждой когорты
print(cohorts)
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: Churn, Length: 72, dtype: float64

# %%
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: customerID, Length: 72, dtype: float64

# %% [markdown]
# **Задание: Используя результаты предыдущего задания, постройте график процента оттока для различных значений tenure.**

# %%
# Создание графика процента оттока
plt.plot(cohorts.index, cohorts.values)
plt.xlabel('Tenure')
plt.ylabel('процента оттока (%)')
plt.show()

# %% [markdown]
# <img src='fig9.png'>

# %% [markdown]
# ### Более крупные когорты (сегменты)
# **Задание: На основе колонки tenure создайте новую колонку с названием "Tenure Cohort", в которой будут следующие 4 категории:**
#    * '0-12 месяцев'
#    * '24-48 месяцев'
#    * '12-24 месяцев'
#    * 'Более 48 месяцев'

# %%
# Напишите Ваш код в этой ячейке
# Определение границ для категорий
bins = [0, 12, 24, 48, df['tenure'].max()]

# Метки для категорий
labels = ['0-12 месяцев', '12-24 месяцев', '24-48 месяцев', 'Более 48 месяцев']

# Создание новой колонки "Tenure Cohort"
df['Tenure Cohort'] = pd.cut(df['tenure'], bins=bins, labels=labels)

# Вывод первых нескольких строк с новой колонкой
print(df[['tenure', 'Tenure Cohort']].head())
# Out:
#    tenure  Tenure Cohort
# 0       1   0-12 месяцев
# 1      34  24-48 месяцев
# 2       2   0-12 месяцев
# 3      45  24-48 месяцев
# 4       2   0-12 месяцев

# %%
# Out:
#    tenure   Tenure Cohort
# 0       1     0-12 Months
# 1      34    24-48 Months
# 2       2     0-12 Months
# 3      45    24-48 Months
# 4       2     0-12 Months
# 5       8     0-12 Months
# 6      22    12-24 Months
# 7      10     0-12 Months
# 8      28    24-48 Months
# 9      62  Over 48 Months

# %% [markdown]
# **Задание: Постройте график scatterplot для Total Charges и Monthly Charts, раскрашивая график разными цветами по колонке "Tenure Cohort", которую Вы создали в предыдущем задании.**

# %%
# Построение scatterplot с раскрашиванием по колонке "Tenure Cohort"
sns.scatterplot(data=df, x='TotalCharges', y='MonthlyCharges', hue='Tenure Cohort')
# Отображение графика
plt.show()

# %% [markdown]
# <img src='fig10.png'>

# %% [markdown]
# **Задание: Постройте график countplot с количеством ушедших и не ушедших в отток людей в каждой когорте.**

# %%
# Построение countplot с количеством ушедших и не ушедших в отток людей в каждой когорте
sns.countplot(data=df, x='Tenure Cohort', hue='Churn')
plt.xlabel('Tenure Cohort')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <img src='cplot.png'>

# %% [markdown]
# **Задание: Создайте набор графиков CountPlot с количеством людей по различным когортам Tenure Cohort. Для каждого типа контракта создайте отдельный график, и раскрасьте эти графики разными цветами по колонке Churn.**

# %%
# Напишите Ваш код в этой ячейке
# Получение уникальных типов контрактов
contract_types = df['Contract'].unique()
# Создание набора графиков
fig, axes = plt.subplots(len(contract_types), 1, figsize=(10, 6 * len(contract_types)), sharex=True)
# Цикл по типам контрактов
for i, contract_type in enumerate(contract_types):
    # Фильтрация данных по типу контракта
    subset_data = df[df['Contract'] == contract_type]
    # Построение countplot с количеством людей в каждой когорте для текущего типа контракта
    sns.countplot(data=subset_data, x='Tenure Cohort', hue='Churn', ax=axes[i])
    # Добавление подписи оси y
    axes[i].set_ylabel('Count')
# Отображение графиков
plt.show()

# %% [markdown]
# <img src='fig11.png'>

# %% [markdown]
# -----
#
# # Часть 4: Предиктивная модель
#
# **Давайте исследуем 4 модели на основе деревьев: одно дерево решений, случайный лес, адаптивный бустинг и градиентный бустинг. При желании Вы можете дополнительно попробовать любые другие модели машинного обучения с учителем (supervised learning models) и сравнить результаты!**
#
#
# ## Одно дерево решений (Decision Tree)

# %% [markdown]
# **Задание: Разделите все данные на признаки X и целевую переменную Y. Создайте дамми-переменные, где это необходимо, а также посмотрите, есть ли какие-то признаки, которые можно было бы удалить.**

# %%
# Разделение данных на признаки и целевую переменную
X = df.drop('Churn', axis=1)
Y = df['Churn']
# Создание дамми-переменных для категориальных признаков
X = pd.get_dummies(X, sparse=True)

# %% [markdown]
# **Задание: Выполните разбиение данных на обучающий и тестовый наборы (train test split), откладывая в сторону 10% данных для тестирования. В решениях мы используем random_state=101.**

# %%
# Разбиение данных на обучающий и тестовый наборы
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=101)

# %% [markdown]
# **Задание: Постройте модель Decision Tree и оцените её работу. Для этого выполните следующие шаги:**
#    1. Обучите модель дерева решений (при желании можете выполнить поиск по сетке для поиска оптимальных значений гиперпараметров).
#    2. Оцените метрики работы модели дерева решений - для этого выведите отчёт "classification report" и нарисуйте график с матрицей ошибок (confusion matrix).
#    2. Посмотрите на важности признаков для получившегося дерева решений.
#    4. Опционально: Нарисуйте график получившегося дерева. Обратите внимание, что если дерево получилось очень большим и Вы не выполняли усечение дерева с помощью параметров, то вызов метода plot_tree может привести к ошибке.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
# Создание и обучение модели дерева решений
dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)
# Предсказание на тестовом наборе
Y_pred = dt.predict(X_test)
# Оценка метрик работы модели
print("Classification Report:")
print(classification_report(Y_test, Y_pred))
# Out:
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.86      0.84      0.85       557
#          Yes       0.43      0.46      0.45       147
#
#     accuracy                           0.76       704
#    macro avg       0.64      0.65      0.65       704
# weighted avg       0.77      0.76      0.76       704

# %%
print("Classification Report:")
print(classification_report(Y_test, Y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.86      0.84      0.85       557
#          Yes       0.43      0.46      0.45       147
#
#     accuracy                           0.76       704
#    macro avg       0.64      0.65      0.65       704
# weighted avg       0.77      0.76      0.76       704

# %%
# Построение матрицы ошибок
cm = confusion_matrix(Y_test, Y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=["Not Churn", "Churn"], yticklabels=["Not Churn", "Churn"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Важности признаков
feature_importances = dt.feature_importances_
indices = np.argsort(feature_importances)[::-1]
print("Feature Importances:")
# Out:
# Feature Importances:

# %%
for i, index in enumerate(indices):
    print(f"{i+1}. {X.columns[index]}: {feature_importances[index]}")
# Out:
# 1. Contract_Month-to-month: 0.17013934290440044
# 2. MonthlyCharges: 0.11170197905082088
# 3. TotalCharges: 0.09481733585489899
# 4. tenure: 0.0803158049378069
# 5. InternetService_Fiber optic: 0.05048185866742801
# 6. SeniorCitizen: 0.01259924897652455
# 7. TechSupport_No: 0.012585694243653653
# 8. PaymentMethod_Electronic check: 0.01103866543501372
# 9. OnlineSecurity_No: 0.00850454421833567
# 10. gender_Female: 0.0061994230904819075
# 11. OnlineBackup_No: 0.006091574401128218
# 12. PaperlessBilling_Yes: 0.005653042846419264
# 13. Dependents_No: 0.004660597768738794
# 14. OnlineSecurity_Yes: 0.0046520936979665
# 15. PaperlessBilling_No: 0.00444954462926488
# 16. MultipleLines_No: 0.004277028973179363
# 17. PaymentMethod_Credit card (automatic): 0.0041918971683949854
# 18. Partner_Yes: 0.003916188208771024
# 19. StreamingTV_No: 0.0038364311974929282
# 20. TechSupport_Yes: 0.0034827770485409324
# 21. StreamingTV_Yes: 0.0033501799688693936
# 22. Partner_No: 0.003326059153907978
# 23. Dependents_Yes: 0.00331942057891202
# 24. StreamingMovies_Yes: 0.003036235546873976
# 25. gender_Male: 0.003019234372426921
# 26. MultipleLines_No phone service: 0.0029126658599658455
# 27. DeviceProtection_Yes: 0.002814012091713532
# 28. PaymentMethod_Bank transfer (automatic): 0.002807473845465504
# 29. MultipleLines_Yes: 0.002744986876655457
# 30. OnlineBackup_Yes: 0.002601771347226238
# 31. DeviceProtection_No: 0.0024849240405831487
# 32. StreamingMovies_No: 0.0019034365655195141
# 33. PaymentMethod_Mailed check: 0.0017106912717621972
# 34. customerID_5294-CDGWY: 0.0007973390476989578
# 35. customerID_2321-OMBXY: 0.0007963619165130778
# 36. customerID_6635-MYYYZ: 0.0007953865804242407
# 37. customerID_8869-TORSS: 0.0007944130350381442
# 38. customerID_6034-ZRYCV: 0.000794328966211714
# 39. customerID_5616-PRTNT: 0.0007941851615590885
# 40. customerID_6682-QJDGB: 0.0007941684503150445
# 41. customerID_3878-AVSOQ: 0.0007934921898634693
# 42. customerID_4355-HBJHH: 0.0007934412759739224
# 43. customerID_3886-CERTZ: 0.0007933710719054983
# 44. customerID_5089-IFSDP: 0.0007930220187061316
# 45. customerID_3594-UVONA: 0.000792471298863881
# 46. customerID_6532-YLWSI: 0.0007915030993540381
# 47. customerID_9741-YLNTD: 0.0007912345911658481
# 48. customerID_6598-RFFVI: 0.000790536673103202
# 49. customerID_4390-KYULV: 0.0007898499306313097
# 50. customerID_8580-QVLOC: 0.0007895720157840914
# 51. customerID_7253-UVNDW: 0.0007886577735317816
# 52. customerID_0516-VRYBW: 0.0007886091230818342
# 53. customerID_8563-IIOXK: 0.000787647990695368
# 54. customerID_3313-QKNKB: 0.0007873915953277593
# 55. customerID_4083-EUGRJ: 0.0007869652964540032
# 56. customerID_7619-ODSGN: 0.0007869157704034961
# 57. customerID_6818-WOBHJ: 0.0007868990591594587
# 58. customerID_4464-JCOLN: 0.0007866886143365186
# 59. customerID_8079-XRJRS: 0.0007857309897298093
# 60. customerID_6270-OMFIW: 0.0007851642728738356
# 61. customerID_8309-IEYJD: 0.0007849138959189968
# 62. customerID_8515-OCTJS: 0.0007847751126134124
# 63. customerID_7317-GGVPB: 0.0007845558377732069
# 64. customerID_8631-NBHFZ: 0.0007838209787378749
# 65. customerID_6240-EURKS: 0.0007835812803882029
# 66. customerID_1447-PJGGA: 0.00078352474902103
# 67. customerID_7145-FEJWU: 0.0007833222452541896
# 68. customerID_2634-HCZGT: 0.0007828685838669232
# 69. customerID_8559-CIZFV: 0.000781917923777341
# 70. customerID_0193-ESZXP: 0.0007815460043352463
# 71. customerID_5365-LLFYV: 0.0007815460043352463
# 72. customerID_1963-VAUKV: 0.0007812067916597544
# 73. customerID_7951-QKZPL: 0.0007809689942581059
# 74. customerID_3034-ZBEQN: 0.0007805447118901345
# 75. customerID_3351-NQLDI: 0.0007800986969198109
# 76. customerID_2667-WYLWJ: 0.0007800217911116502
# 77. customerID_7854-EDSSA: 0.0007798434385675354
# 78. customerID_7776-QWNFX: 0.0007797619906725597
# 79. customerID_3976-BWUCK: 0.0007796957533780128
# 80. customerID_4234-XTNEA: 0.0007792740682761326
# 81. customerID_6481-OGDOO: 0.0007790763101527679
# 82. customerID_9249-FXSCK: 0.0007788323029313039
# 83. customerID_8739-XNIKG: 0.0007782635322942752
# 84. customerID_6323-AYBRX: 0.0007781325472089253
# 85. customerID_8182-PNAGI: 0.000777882507439924
# 86. customerID_7666-WKRON: 0.0007773710790984119
# 87. customerID_4190-MFLUW: 0.0007773710790984119
# 88. customerID_0607-DAAHE: 0.0007771904981202761
# 89. customerID_0187-QSXOE: 0.0007768327334757675
# 90. customerID_9840-EFJQB: 0.0007764739615542789
# 91. customerID_4106-HADHQ: 0.0007762501587395899
# 92. customerID_2889-FPWRM: 0.000775886712493956
# 93. customerID_0617-AQNWT: 0.0007753115249321844
# 94. customerID_0823-HSCDJ: 0.0007750331209657856
# 95. customerID_1043-YCUTE: 0.0007743745925757246
# 96. customerID_4140-WJAWW: 0.0007742093379455387
# 97. customerID_5271-YNWVR: 0.0007741970734374471
# 98. customerID_7614-QVWQL: 0.0007737867490166174
# 99. customerID_3705-PSNGL: 0.0007734393575605933
# 100. customerID_4541-RMRLG: 0.0007728178220038713
# 101. customerID_3982-XWFZQ: 0.0007727053210737054
# 102. customerID_6261-RCVNS: 0.000772505815789217
# 103. customerID_8035-BUYVG: 0.0007715739631766896
# 104. customerID_8496-EJAUI: 0.0007712339390002667
# 105. customerID_3863-IUBJR: 0.000770733733224244
# 106. customerID_0203-HHYIJ: 0.000770643795650301
# 107. customerID_4597-ELFTS: 0.0007697153091494225
# 108. customerID_1038-ZAGBI: 0.0007687884996261371
# 109. customerID_4273-MBHYA: 0.0007681694272061007
# 110. customerID_7359-SSBJK: 0.0007678633630441722
# 111. customerID_2834-JRTUA: 0.0007673604848841226
# 112. customerID_3230-WYKIR: 0.0007671425122681707
# 113. customerID_3104-OWCGK: 0.0007671161735940644
# 114. customerID_2898-LSJGD: 0.0007669398953795936
# 115. customerID_6946-LMSQS: 0.0007660180926207627
# 116. customerID_7547-EKNFS: 0.000765915084248541
# 117. customerID_4765-OXPPD: 0.0007658867204612359
# 118. customerID_9170-GYZJC: 0.0007657440118748436
# 119. customerID_0348-SDKOL: 0.0007656315170200182
# 120. customerID_8734-DKSTZ: 0.0007656088407122593
# 121. customerID_0687-ZVTHB: 0.0007650979507677332
# 122. customerID_6680-NENYN: 0.0007650349778938087
# 123. customerID_5020-ZSTTY: 0.0007641794658329029
# 124. customerID_0378-XSZPU: 0.0007632626338402622
# 125. customerID_5022-KVDQT: 0.0007631400295954669
# 126. customerID_0565-IYCGT: 0.0007623474508260071
# 127. customerID_7801-KICAO: 0.0007615632939971293
# 128. customerID_8718-PTMEZ: 0.0007615632939971293
# 129. customerID_9290-SHCMB: 0.0007615632939971293
# 130. customerID_0628-CNQRM: 0.0007614339128382834
# 131. customerID_2382-BCKQJ: 0.0007606278893465274
# 132. customerID_2794-XIMMO: 0.0007605314854087104
# 133. customerID_0022-TCJCI: 0.0007605220159366824
# 134. customerID_5032-MIYKT: 0.0007599974120230616
# 135. customerID_1891-FZYSA: 0.0007598363931037118
# 136. customerID_4248-HCETZ: 0.0007598363931037118
# 137. customerID_2325-ZUSFD: 0.0007596117561928534
# 138. customerID_4250-FDVOU: 0.0007590484461713987
# 139. customerID_6776-TLWOI: 0.0007590287626917044
# 140. customerID_2530-ENDWQ: 0.0007589740314974117
# 141. customerID_3948-XHGNA: 0.000758876352575524
# 142. customerID_3400-ESFUW: 0.0007587031296902483
# 143. customerID_6439-GTPCA: 0.0007579368021209519
# 144. customerID_2011-TRQYE: 0.0007560872003745814
# 145. customerID_1555-DJEQW: 0.0007560345663891703
# 146. customerID_7315-WYOAW: 0.0007553464507808259
# 147. customerID_6559-ILWKJ: 0.0007540312163026581
# 148. customerID_5572-ZDXHY: 0.0007535044231611806
# 149. customerID_5759-RCVCB: 0.0007535044231611806
# 150. customerID_3481-JHUZH: 0.0007535044231611806
# 151. customerID_9033-EOXWV: 0.0007534138740506656
# 152. customerID_9314-IJWSQ: 0.0007532603110233459
# 153. customerID_1009-IRMNA: 0.0007523013488721015
# 154. customerID_9259-PACGQ: 0.000752100670856097
# 155. customerID_5043-TRZWM: 0.000751955111366729
# 156. customerID_3999-QGRJH: 0.0007508971414201386
# 157. customerID_1751-NCDLI: 0.0007508971414201386
# 158. customerID_9050-IKDZA: 0.0007508971414201386
# 159. customerID_0719-SYFRB: 0.0007508971414201386
# 160. customerID_0917-EZOLA: 0.000750724313763752
# 161. customerID_7339-POGZN: 0.0007502841641618355
# 162. customerID_4710-FDUIZ: 0.0007502841641618355
# 163. customerID_5624-BQSSA: 0.0007493208001634354
# 164. customerID_1625-JAIIY: 0.0007476139293553875
# 165. Contract_One year: 0.0007475572518536492
# 166. customerID_6804-GDMOI: 0.0007471920568407653
# 167. customerID_2332-EFBJY: 0.0007456438148112852
# 168. customerID_8624-GIOUT: 0.0007454153315595964
# 169. customerID_8444-WRIDW: 0.0007452146765661458
# 170. customerID_3814-MLAXC: 0.0007450426087834348
# 171. customerID_3466-RITXD: 0.0007446396652416373
# 172. customerID_9692-TUSXH: 0.0007446396652416373
# 173. customerID_0322-YINQP: 0.0007446396652416373
# 174. customerID_4903-UYAVB: 0.0007442903401151695
# 175. customerID_0021-IKXGC: 0.0007440397944049831
# 176. customerID_3370-HXOPH: 0.000743852519718126
# 177. customerID_3259-FDWOY: 0.0007426083752365693
# 178. customerID_4789-KWMXN: 0.0007426075446554299
# 179. customerID_7136-RVDTZ: 0.0007412782180896735
# 180. customerID_3797-FKOGQ: 0.0007412081460469765
# 181. customerID_0520-FDVVT: 0.0007408404832761189
# 182. customerID_5995-OIGLP: 0.0007399370192721238
# 183. customerID_5688-KZTSN: 0.000739074265782105
# 184. customerID_4489-SNOJF: 0.0007388187357050914
# 185. customerID_7762-URZQH: 0.0007385037771100552
# 186. customerID_5906-CVLHP: 0.0007385025251434921
# 187. customerID_8257-RZAHR: 0.0007385025251434921
# 188. customerID_8651-ENBZX: 0.0007372239542897123
# 189. customerID_4115-NZRKS: 0.000736995157400088
# 190. customerID_3707-LRWZD: 0.000736671343516204
# 191. customerID_8443-WVPSS: 0.000736456811777443
# 192. customerID_6786-OBWQR: 0.000736456811777443
# 193. customerID_4588-YBNIB: 0.000736456811777443
# 194. customerID_3571-RFHAR: 0.000736456811777443
# 195. customerID_0840-DFEZH: 0.000736456811777443
# 196. customerID_2369-FEVNO: 0.000736456811777443
# 197. customerID_5295-PCJOO: 0.000736456811777443
# 198. customerID_1866-OBPNR: 0.0007362488017934019
# 199. customerID_9378-FXTIZ: 0.0007350227057007296
# 200. customerID_7551-DACSP: 0.0007325911581875295
# 201. customerID_9063-ZGTUY: 0.0007323093195314722
# 202. customerID_2091-MJTFX: 0.0007319757253565757
# 203. customerID_0587-DMGBH: 0.0007313425283623224
# 204. customerID_1391-UBDAR: 0.0007313425283623224
# 205. customerID_8073-IJDCM: 0.0007313425283623224
# 206. customerID_0365-GXEZS: 0.0007313425283623224
# 207. customerID_4139-SUGLD: 0.0007300152279478716
# 208. customerID_9986-BONCE: 0.0007299770643437208
# 209. customerID_6797-LNAQX: 0.0007299661611897083
# 210. customerID_6435-SRWBJ: 0.0007294429373795653
# 211. customerID_3092-IGHWF: 0.0007288460443082902
# 212. customerID_9617-INGJY: 0.0007285795434413923
# 213. customerID_7845-URHJN: 0.0007261929821334948
# 214. customerID_1114-CENIM: 0.0007258855535706748
# 215. customerID_3791-LGQCY: 0.0007256037640249361
# 216. customerID_8166-ZZTFS: 0.0007227469142303908
# 217. customerID_5440-FLBQG: 0.0007215757455438518
# 218. customerID_4652-NNHNY: 0.0007214769106776691
# 219. customerID_1941-HOSAM: 0.000721029496359097
# 220. customerID_9139-WQQDY: 0.0007208612557633338
# 221. customerID_0674-EYYZV: 0.0007208612557633338
# 222. customerID_6345-ULYRW: 0.0007204807645378247
# 223. customerID_6214-EDAKZ: 0.0007198782605497215
# 224. customerID_1577-HKTFG: 0.0007195459417490893
# 225. customerID_1934-SJVJK: 0.0007193479681569
# 226. customerID_7133-VBDCG: 0.0007180453914830075
# 227. customerID_3545-CNWRG: 0.0007180453914830075
# 228. customerID_4537-DKTAL: 0.0007180453914830075
# 229. customerID_3223-DWFIO: 0.0007180453914830075
# 230. customerID_1197-BVMVG: 0.0007180453914830075
# 231. customerID_6807-SIWJI: 0.0007180453914830075
# 232. customerID_7398-SKNQZ: 0.0007179556470271259
# 233. customerID_4322-RCYMT: 0.0007167240232784784
# 234. customerID_0883-EIBTI: 0.0007160727393086013
# 235. customerID_8945-MUQUF: 0.0007148838344627489
# 236. customerID_8053-WWDRO: 0.0007136455483371667
# 237. customerID_7577-SWIFR: 0.0007135962025822025
# 238. customerID_3090-HAWSU: 0.0007133291655947728
# 239. customerID_2484-DGXPZ: 0.0007132890205164923
# 240. customerID_1965-DDBWU: 0.0007126494518798081
# 241. customerID_3855-ONCAR: 0.0007107924077306535
# 242. customerID_7931-PXHFC: 0.0007103171409890461
# 243. customerID_2856-NNASM: 0.000709180633563464
# 244. customerID_8919-FYFQZ: 0.000709180633563464
# 245. customerID_1216-JWVUX: 0.000709180633563464
# 246. customerID_6362-QHAFM: 0.000709180633563464
# 247. customerID_0265-EDXBD: 0.000709180633563464
# 248. customerID_5183-SNMJQ: 0.000709180633563464
# 249. customerID_6712-OAWRH: 0.000709180633563464
# 250. customerID_0004-TLHLJ: 0.000709180633563464
# 251. customerID_2810-FTLEM: 0.000709180633563464
# 252. customerID_4160-AMJTL: 0.0007074934315411636
# 253. customerID_6839-ITVZJ: 0.0007071133580011975
# 254. customerID_2869-ADAWR: 0.0007069985393063453
# 255. customerID_9614-RMGHA: 0.0007067569130112959
# 256. customerID_4927-WWOOZ: 0.0007067375900423315
# 257. customerID_5542-TBBWB: 0.0007062772671710986
# 258. customerID_0447-BEMNG: 0.0007052689490343837
# 259. customerID_1527-SXDPN: 0.0007052231523493848
# 260. customerID_1324-NLTJE: 0.0007047019231163089
# 261. customerID_7410-KTVFV: 0.0007024780117218587
# 262. customerID_4174-LPGTI: 0.0007024780117218587
# 263. customerID_4946-EDSEW: 0.0007014205265493879
# 264. customerID_4510-PYUSH: 0.0007010175531908458
# 265. customerID_4847-TAJYI: 0.0007001453995300844
# 266. customerID_7402-EYFXX: 0.0006995450271291777
# 267. customerID_2920-RNCEZ: 0.0006990703562815944
# 268. customerID_4815-GBTCD: 0.0006980996861640349
# 269. customerID_6339-YPSAH: 0.0006980996861640349
# 270. customerID_3384-CTMSF: 0.0006980996861640349
# 271. customerID_4282-YMKNA: 0.0006980996861640349
# 272. customerID_0177-PXBAT: 0.0006980996861640349
# 273. customerID_0311-UNPFF: 0.0006980996861640349
# 274. customerID_9667-TKTVZ: 0.0006980996861640349
# 275. customerID_3063-QFSZL: 0.0006980996861640349
# 276. customerID_6715-OFDBP: 0.0006980996861640349
# 277. customerID_1725-IQNIY: 0.0006972545291589926
# 278. customerID_2876-GZYZC: 0.0006957804181036884
# 279. customerID_5577-OTWWW: 0.0006954254793139249
# 280. customerID_8875-AKBYH: 0.0006953403988669433
# 281. customerID_9863-JZAIC: 0.0006950002351377058
# 282. customerID_2929-QNSRW: 0.0006935440185086406
# 283. customerID_5133-POWUA: 0.0006931358228493568
# 284. customerID_6425-YQLLO: 0.0006931358228493568
# 285. customerID_5057-LCOUI: 0.0006924094699318954
# 286. customerID_7465-ZZRVX: 0.0006919731953041244
# 287. customerID_4877-EVATK: 0.0006911382439154516
# 288. customerID_4248-QPAVC: 0.0006907603573670103
# 289. customerID_4488-PSYCG: 0.000689506964596363
# 290. customerID_5687-DKDTV: 0.0006894299341606385
# 291. customerID_1150-WFARN: 0.000689420208606647
# 292. customerID_3521-SYVOR: 0.0006890600621878043
# 293. customerID_5708-EVONK: 0.0006886349408828043
# 294. customerID_3318-OSATS: 0.0006857523447760998
# 295. customerID_4813-HQMGZ: 0.000685076103979016
# 296. customerID_9605-WGJVW: 0.0006849835670687208
# 297. customerID_5999-LCXAO: 0.0006838527537933404
# 298. customerID_4803-AXVYP: 0.0006838527537933404
# 299. customerID_5226-NOZFC: 0.0006838527537933404
# 300. customerID_7880-XSOJX: 0.0006838527537933404
# 301. customerID_0946-CLJTI: 0.0006838527537933404
# 302. customerID_5685-IIXLY: 0.0006838527537933404
# 303. customerID_1469-LBJQJ: 0.0006838527537933404
# 304. customerID_5876-HZVZM: 0.000683663685235371
# 305. customerID_4580-TMHJU: 0.000683195721233026
# 306. customerID_8784-CGILN: 0.0006823239432891752
# 307. customerID_7758-XKCBS: 0.0006817599840665721
# 308. customerID_5748-RNCJT: 0.0006817171895160657
# 309. customerID_4432-ADRLB: 0.0006802535287733753
# 310. customerID_4749-OJKQU: 0.0006798883900032329
# 311. customerID_4912-PIGUY: 0.0006780993101132638
# 312. customerID_5174-RNGBH: 0.0006778943714359155
# 313. customerID_0733-VUNUW: 0.0006774059269852751
# 314. customerID_4195-SMMNX: 0.0006766627131576613
# 315. customerID_3315-TOTBP: 0.0006763846037603153
# 316. customerID_7994-UYIVZ: 0.0006746169268190327
# 317. customerID_4720-VSTSI: 0.0006741881680915823
# 318. customerID_3085-QUOZK: 0.0006741881680915823
# 319. customerID_3404-JNXAX: 0.0006741881680915823
# 320. customerID_6990-YNRIO: 0.0006741425540770045
# 321. customerID_5445-PZWGX: 0.0006731456650230902
# 322. customerID_1518-VOWAV: 0.0006721977800793179
# 323. customerID_3030-YZADT: 0.0006719250894829901
# 324. customerID_5766-XQXMQ: 0.0006716894212723302
# 325. customerID_1640-PLFMP: 0.0006713183170121254
# 326. customerID_0843-WTBXE: 0.0006712011449110894
# 327. customerID_9831-BPFRI: 0.000669026677830341
# 328. customerID_4929-XIHVW: 0.0006674641257067894
# 329. customerID_2079-FBMZK: 0.0006674641257067894
# 330. customerID_4791-QRGMF: 0.0006669797540625907
# 331. customerID_9631-XEYKE: 0.0006669797540625907
# 332. customerID_3192-NQECA: 0.0006666934650816751
# 333. customerID_1218-VKFPE: 0.0006665726940535432
# 334. customerID_8035-PWSEV: 0.0006659919654066637
# 335. customerID_7693-LCKZL: 0.0006648568439657476
# 336. customerID_6563-VNPMN: 0.0006648568439657476
# 337. customerID_5955-ERIHD: 0.0006648568439657476
# 338. customerID_8450-JOVAH: 0.0006648568439657476
# 339. customerID_4581-LNWUM: 0.0006648568439657476
# 340. customerID_8433-WXGNA: 0.0006648568439657476
# 341. customerID_2577-GVSIL: 0.0006648568439657476
# 342. customerID_1450-SKCVI: 0.0006648568439657476
# 343. customerID_5760-FXFVO: 0.0006648568439657476
# 344. customerID_7401-RUBNK: 0.0006648568439657476
# 345. customerID_3565-UNOCC: 0.0006648568439657476
# 346. customerID_6967-QIQRV: 0.0006648568439657476
# 347. customerID_5939-XAIXZ: 0.0006648568439657476
# 348. customerID_3716-UVSPD: 0.0006648568439657476
# 349. customerID_1628-BIZYP: 0.0006646385327632513
# 350. customerID_4760-XOHVN: 0.0006645560037648578
# 351. customerID_9957-YODKZ: 0.0006643954582308672
# 352. customerID_7854-EKTJL: 0.0006642468835584418
# 353. customerID_2150-UWTFY: 0.0006610179216031079
# 354. customerID_0117-LFRMW: 0.0006594071977037329
# 355. customerID_5013-SBUIH: 0.0006593671632675893
# 356. customerID_2262-SLNVK: 0.0006580579532309426
# 357. customerID_1862-SKORY: 0.000655966866251269
# 358. customerID_4925-LMHOK: 0.0006555322956976714
# 359. customerID_6771-XWBDM: 0.0006544211162883117
# 360. customerID_1173-XZPYF: 0.0006544045490845374
# 361. customerID_5394-SVGJV: 0.0006538937789854615
# 362. customerID_6646-QVXLR: 0.0006536341964716953
# 363. customerID_0268-QKIWO: 0.00065216966749374
# 364. customerID_4853-RULSV: 0.0006521609647619342
# 365. customerID_8775-ERLNB: 0.0006515746236424625
# 366. customerID_2947-DOMLJ: 0.0006515597070864324
# 367. customerID_9133-AYJZG: 0.0006515597070864324
# 368. customerID_2789-HQBOU: 0.0006509569691520333
# 369. customerID_9025-ZRPVR: 0.0006501146734191927
# 370. customerID_2254-DLXRI: 0.0006451866371361589
# 371. customerID_9412-ARGBX: 0.000645072258623215
# 372. customerID_1120-BMWUB: 0.0006447639353663483
# 373. customerID_2545-EBUPK: 0.0006446373170086434
# 374. customerID_6103-BOCOU: 0.0006435814249588439
# 375. customerID_2995-UPRYS: 0.0006422768002084209
# 376. customerID_8445-DNBAE: 0.0006422768002084209
# 377. customerID_9820-RMCQV: 0.0006413830399610382
# 378. customerID_9048-JVYVF: 0.000640418862674034
# 379. customerID_7812-FZHPE: 0.0006394789850764717
# 380. customerID_5515-IDEJJ: 0.0006394784187171292
# 381. customerID_9873-MNDKV: 0.0006382625702071174
# 382. customerID_9306-CPCBC: 0.0006382625702071174
# 383. customerID_1264-BYWMS: 0.0006382625702071174
# 384. customerID_6851-WEFYX: 0.0006382625702071174
# 385. customerID_7537-RBWEA: 0.0006382625702071174
# 386. customerID_8642-GVWRF: 0.0006382625702071174
# 387. customerID_8245-UMPYT: 0.0006382625702071174
# 388. customerID_3237-AJGEH: 0.0006382625702071174
# 389. customerID_3312-UUMZW: 0.0006382625702071174
# 390. customerID_4570-QHXHL: 0.0006382625702071174
# 391. customerID_4077-CROMM: 0.0006382625702071174
# 392. customerID_2360-RDGRO: 0.0006382625702071174
# 393. customerID_2916-BQZLN: 0.0006382625702071174
# 394. customerID_6892-XPFPU: 0.0006382625702071174
# 395. customerID_0397-GZBBC: 0.0006382625702071161
# 396. customerID_3285-UCQVC: 0.0006381359977778049
# 397. customerID_6386-SZZKH: 0.0006380985044759443
# 398. customerID_3211-ILJTT: 0.0006353915974718106
# 399. customerID_4566-NECEV: 0.0006350871345344467
# 400. customerID_0727-BMPLR: 0.0006349589337153625
# 401. customerID_0570-BFQHT: 0.0006342780622920628
# 402. customerID_7083-YNSKY: 0.0006342587484635959
# 403. customerID_1725-MIMXW: 0.0006312486958092378
# 404. customerID_6175-IRFIT: 0.0006312486958092378
# 405. customerID_2038-OEQZH: 0.0006312486958092378
# 406. customerID_4661-NJEUX: 0.0006312486958092378
# 407. customerID_9053-JZFKV: 0.000631237230234256
# 408. customerID_6927-WTFIV: 0.0006306942393350957
# 409. customerID_2223-KAGMX: 0.0006291021732728332
# 410. customerID_1449-XQEMT: 0.0006289828115548511
# 411. customerID_7530-HDYDS: 0.000627204236986056
# 412. customerID_6630-UJZMY: 0.0006257476178501146
# 413. customerID_8785-EPNCG: 0.0006240082285499775
# 414. customerID_3966-HRMZA: 0.0006238337621040308
# 415. customerID_2037-SGXHH: 0.0006234112225237268
# 416. customerID_4628-CTTLA: 0.0006223275397768447
# 417. customerID_4895-TMWIR: 0.0006189759041261881
# 418. customerID_9261-WDCAF: 0.0006189212802008418
# 419. customerID_6097-EQISJ: 0.0006189212802008418
# 420. customerID_4583-PARNH: 0.0006188282932296572
# 421. customerID_6770-XUAGN: 0.0006188282932296572
# 422. customerID_8066-POXGX: 0.0006178777121340677
# 423. customerID_0137-UDEUO: 0.0006178503724122917
# 424. customerID_4088-YLDSU: 0.0006170727665684504
# 425. customerID_8161-QYMTT: 0.0006166126161296778
# 426. customerID_7893-IXHRQ: 0.0006157940328387146
# 427. customerID_6861-OKBCE: 0.000614004210117143
# 428. customerID_1585-MQSSU: 0.0006128771270738803
# 429. customerID_1383-EZRWL: 0.0006090921764362087
# 430. customerID_6969-MVBAI: 0.0006076762014031556
# 431. customerID_2839-RFSQE: 0.0006070108921945332
# 432. customerID_5371-VYLSX: 0.0006067693512824243
# 433. customerID_7963-GQRMY: 0.0006067693512824243
# 434. customerID_3194-ORPIK: 0.0006067693512824243
# 435. customerID_8132-YPVBX: 0.0006047767570691749
# 436. customerID_5108-ADXWO: 0.0006044153126961341
# 437. customerID_3842-IYKUE: 0.000602116067506612
# 438. customerID_3763-GCZHZ: 0.0005999318563859926
# 439. customerID_1960-UYCNN: 0.0005989326589369268
# 440. customerID_5590-YRFJT: 0.0005985690336298768
# 441. customerID_5832-XKAES: 0.0005983711595691728
# 442. customerID_5447-WZAFP: 0.0005983711595691728
# 443. customerID_2971-SGAFL: 0.0005983711595691728
# 444. customerID_5649-VUKMC: 0.0005983711595691728
# 445. customerID_0928-XUTSN: 0.0005983711595691728
# 446. customerID_6557-BZXLQ: 0.0005983711595691728
# 447. customerID_3627-FCRDW: 0.0005972047440534437
# 448. customerID_7124-UGSUR: 0.000596816948765098
# 449. customerID_2103-ZRXFN: 0.000596816948765098
# 450. customerID_0278-YXOOG: 0.0005964541810259261
# 451. customerID_7587-AOVVU: 0.0005940751615004706
# 452. customerID_7434-SHXLS: 0.0005934015225536709
# 453. customerID_0691-JVSYA: 0.0005925351071315349
# 454. customerID_2027-OAQQC: 0.0005912111627880039
# 455. customerID_3338-CVVEH: 0.0005903764780949745
# 456. customerID_0080-OROZO: 0.0005874916839406423
# 457. customerID_0644-OQMDK: 0.0005874916839406423
# 458. customerID_7627-JKIAZ: 0.0005874916839406423
# 459. customerID_5949-EBSQK: 0.0005861704882496212
# 460. customerID_3927-NLNRY: 0.0005861637618935661
# 461. customerID_3009-JWMPU: 0.0005834953671699431
# 462. customerID_3462-BJQQA: 0.0005820023436539028
# 463. customerID_4132-KALRO: 0.0005814866832226066
# 464. customerID_5202-IVJNU: 0.0005801515249028038
# 465. customerID_5136-KCKGI: 0.0005798946307503212
# 466. customerID_0257-ZESQC: 0.0005781363860571725
# 467. customerID_6734-GMPVK: 0.0005759487148109502
# 468. customerID_8064-RAVOH: 0.0005758760031943912
# 469. customerID_8849-GYOKR: 0.0005758760031943912
# 470. customerID_1794-HBQTJ: 0.0005749056238997935
# 471. customerID_3597-MVHJT: 0.0005749056238997935
# 472. customerID_8800-JOOCF: 0.0005738051275461037
# 473. customerID_4913-EHYUI: 0.0005737255389338303
# 474. customerID_5143-WMWOG: 0.0005722086110338964
# 475. customerID_9547-ITEFG: 0.0005704894852866812
# 476. customerID_3990-QYKBE: 0.0005692015509999243
# 477. customerID_2761-OCIAX: 0.000567344506850771
# 478. customerID_5498-TXHLF: 0.000567344506850771
# 479. customerID_5533-NHFRF: 0.000567344506850771
# 480. customerID_2208-NQBCT: 0.000567344506850771
# 481. customerID_2000-MPKCA: 0.000567344506850771
# 482. customerID_6365-MTGZX: 0.000567344506850771
# 483. customerID_4559-UWIHT: 0.0005657798810070038
# 484. customerID_1432-FPAXX: 0.0005625711756633257
# 485. customerID_9667-EQRXU: 0.0005623715938715147
# 486. customerID_4445-ZJNMU: 0.0005598013352168749
# 487. customerID_0916-QOFDP: 0.0005579218271041216
# 488. customerID_5968-VXZLG: 0.0005560182099807907
# 489. customerID_4137-BTIKL: 0.0005545695470372643
# 490. customerID_8329-IBCTI: 0.000552131115909902
# 491. customerID_5339-PXDVH: 0.0005494107605532067
# 492. customerID_7663-RGWBC: 0.000548981794017432
# 493. customerID_7586-ZATGZ: 0.000548981794017432
# 494. customerID_8714-CTZJW: 0.0005470822030346715
# 495. customerID_6121-VZNQB: 0.0005470822030346715
# 496. customerID_4059-IIEBK: 0.0005470822030346715
# 497. customerID_1322-AGOQM: 0.0005457780062405387
# 498. customerID_7858-GTZSP: 0.0005443236238814141
# 499. customerID_2688-BHGOG: 0.0005429664225720269
# 500. customerID_5150-ITWWB: 0.000539306816288039
# 501. customerID_2482-CZGBB: 0.0005374842696480982
# 502. customerID_0248-IPDFW: 0.0005371701350661894
# 503. customerID_5073-WXOYN: 0.0005355919941633495
# 504. customerID_3320-VEOYC: 0.0005343590473312645
# 505. customerID_4892-VLANZ: 0.0005330921119130063
# 506. customerID_0325-XBFAC: 0.0005318854751725979
# 507. customerID_7379-POKDZ: 0.0005318854751725979
# 508. customerID_5692-FPTAH: 0.0005318854751725979
# 509. customerID_3550-SAHFP: 0.0005318854751725979
# 510. customerID_3669-LVWZB: 0.0005318854751725979
# 511. customerID_8685-WHQPW: 0.0005318854751725975
# 512. customerID_2565-JSLRY: 0.0005304242513397067
# 513. customerID_7855-DIWPO: 0.0005304242513397067
# 514. customerID_7721-JXEAW: 0.0005297257119393452
# 515. customerID_2215-ZAFGX: 0.000529479056031431
# 516. customerID_1200-TUZHR: 0.0005246656100675228
# 517. customerID_2754-SDJRD: 0.0005199175049990331
# 518. customerID_8622-ZLFKO: 0.0005152335635125441
# 519. customerID_4786-UKSNZ: 0.0005150211928651116
# 520. customerID_7016-BPGEU: 0.0005143713434773386
# 521. customerID_6899-PPEEA: 0.0005128895653450051
# 522. customerID_9944-HKVVB: 0.0005128895653450051
# 523. customerID_7279-BUYWN: 0.0005128895653450051
# 524. customerID_9699-UBQFS: 0.0005128895653450051
# 525. customerID_8637-XJIVR: 0.0005114283415121136
# 526. customerID_3132-TVFDZ: 0.0005106807386208659
# 527. customerID_2858-MOFSQ: 0.000507981472664037
# 528. customerID_1394-SUIUH: 0.0004990743581976651
# 529. customerID_3569-EDBPQ: 0.0004981561523567759
# 530. customerID_1029-QFBEN: 0.0004978538197696048
# 531. customerID_3523-QRQLL: 0.0004976145038341599
# 532. customerID_6284-AHOOQ: 0.0004909712078516297
# 533. customerID_1855-AGAWH: 0.0004895764032838686
# 534. customerID_8627-EHGIP: 0.00048756168557487835
# 535. customerID_9540-JYROE: 0.00048629529158637574
# 536. customerID_6849-WLEYG: 0.0004815307437115848
# 537. customerID_4667-OHGKG: 0.00047869692765533864
# 538. customerID_3916-NRPAP: 0.00047869692765533864
# 539. customerID_1475-VWVDO: 0.00047869692765533864
# 540. customerID_0431-APWVY: 0.00047781045186338206
# 541. customerID_5536-SLHPM: 0.00047489774568981963
# 542. customerID_5630-IXDXV: 0.00047489774568981963
# 543. customerID_7176-WIONM: 0.00047489774568981963
# 544. customerID_1536-HBSWP: 0.00047489774568981963
# 545. customerID_0491-KAPQG: 0.0004744344308159756
# 546. customerID_1066-JKSGK: 0.00046599749391443995
# 547. customerID_8017-LXHFA: 0.00046419096015063116
# 548. customerID_9779-DPNEJ: 0.00046419096015063116
# 549. customerID_4255-DDUOU: 0.00045970101782774484
# 550. customerID_6338-AVWCY: 0.00045567658791960684
# 551. customerID_2831-EBWRN: 0.0004541853379862406
# 552. customerID_3900-AQPHZ: 0.0004512039226790588
# 553. customerID_2637-FKFSY: 0.0004434986241512712
# 554. customerID_7239-HZZCX: 0.00043710380009533655
# 555. customerID_6496-JDSSB: 0.00043437313805762197
# 556. customerID_2740-TVLFN: 0.00043318470265937635
# 557. customerID_8976-OQHGT: 0.00042550838013807846
# 558. customerID_8378-LKJAF: 0.00042550838013807846
# 559. customerID_4745-LSPLO: 0.00042365445240009696
# 560. customerID_0988-JRWWP: 0.00042322643363272854
# 561. customerID_7989-CHGTL: 0.00042237964204882813
# 562. customerID_9833-TGFHX: 0.00041425695662481186
# 563. customerID_1193-RTSLK: 0.00041366768641624106
# 564. customerID_7551-JOHTI: 0.00041081643869100387
# 565. customerID_6599-CEBNN: 0.0003989141063794499
# 566. customerID_1349-WXNGG: 0.0003985532614166446
# 567. customerID_6141-OOXUQ: 0.00039588437898922417
# 568. customerID_8123-QBNAZ: 0.00038855270101894327
# 569. customerID_3148-BLQJT: 0.00038610945605122043
# 570. customerID_1626-ERCMM: 0.00037991819655185544
# 571. customerID_3506-LCJDC: 0.0003766921522450915
# 572. customerID_9318-NKNFC: 0.0003754485707100689
# 573. customerID_4211-MMAZN: 0.00035886248927307696
# 574. customerID_4884-ZTHVF: 0.00035617330926736475
# 575. customerID_0533-BNWKF: 0.00035617330926736475
# 576. customerID_2905-KFQUV: 0.00035617330926736475
# 577. customerID_1320-REHCS: 0.00035617330926736475
# 578. customerID_7363-QTBIW: 0.00035539620386532676
# 579. customerID_0114-PEGZZ: 0.0002770236849857282
# 580. customerID_3247-MHJKM: 0.0
# 581. customerID_3282-ZISZV: 0.0
# 582. customerID_3244-DCJWY: 0.0
# 583. customerID_3221-CJMSG: 0.0
# 584. customerID_3280-NMUVX: 0.0
# 585. customerID_3247-ZVOUO: 0.0
# 586. customerID_3283-WCWXT: 0.0
# 587. customerID_3262-EIDHV: 0.0
# 588. customerID_3249-VHRIP: 0.0
# 589. customerID_3276-HDUEG: 0.0
# 590. customerID_3266-FTKHB: 0.0
# 591. customerID_3229-USWAR: 0.0
# 592. customerID_3269-ATYWD: 0.0
# 593. customerID_3261-CQXOL: 0.0
# 594. customerID_3230-IUALN: 0.0
# 595. customerID_3272-VUHPV: 0.0
# 596. customerID_3230-JCNZS: 0.0
# 597. customerID_3274-NSDWE: 0.0
# 598. customerID_3259-KNMRR: 0.0
# 599. customerID_3258-ZKPAI: 0.0
# 600. customerID_3258-SYSWS: 0.0
# 601. customerID_3258-SANFR: 0.0
# 602. customerID_3256-EZDBI: 0.0
# 603. customerID_3275-RHRNE: 0.0
# 604. customerID_3255-GRXMG: 0.0
# 605. customerID_3223-WZWJM: 0.0
# 606. customerID_3254-YRILK: 0.0
# 607. customerID_3278-FSIXX: 0.0
# 608. customerID_3279-DYZQM: 0.0
# 609. customerID_3227-WLKLI: 0.0
# 610. customerID_3224-DFQNQ: 0.0
# 611. customerID_3234-VKACU: 0.0
# 612. customerID_3235-ETOOB: 0.0
# 613. customerID_3280-MRDOF: 0.0
# 614. customerID_3239-TPHPZ: 0.0
# 615. customerID_3243-ZHOHY: 0.0
# 616. customerID_3244-CQPHU: 0.0
# 617. customerID_3253-HKOKL: 0.0
# 618. customerID_3251-YMVWZ: 0.0
# 619. customerID_3249-ZPQRG: 0.0
# 620. customerID_3259-QMXUN: 0.0
# 621. customerID_3392-EHMNK: 0.0
# 622. customerID_3284-SVCRO: 0.0
# 623. customerID_3422-GALYP: 0.0
# 624. customerID_3453-RTHJQ: 0.0
# 625. customerID_3454-JFUBC: 0.0
# 626. customerID_3457-PQBYH: 0.0
# 627. customerID_3458-IDMFK: 0.0
# 628. customerID_3460-TJBWI: 0.0
# 629. customerID_3466-BYAVD: 0.0
# 630. customerID_3466-WAESX: 0.0
# 631. customerID_3468-DRVQJ: 0.0
# 632. customerID_3470-BTGQO: 0.0
# 633. customerID_3470-OBUET: 0.0
# 634. customerID_3472-OAOOR: 0.0
# 635. customerID_3472-QPRCH: 0.0
# 636. customerID_3473-XIIIT: 0.0
# 637. customerID_3474-BAFSJ: 0.0
# 638. customerID_3482-ABPKK: 0.0
# 639. customerID_3486-HOOGQ: 0.0
# 640. customerID_3486-KHMLI: 0.0
# 641. customerID_3452-SRFEG: 0.0
# 642. customerID_3452-GWUIN: 0.0
# 643. customerID_3452-FLHYD: 0.0
# 644. customerID_3429-IFLEM: 0.0
# 645. customerID_3422-WJOYD: 0.0
# 646. customerID_3423-HHXAO: 0.0
# 647. customerID_3424-NMNBO: 0.0
# 648. customerID_3426-NIYYL: 0.0
# 649. customerID_3427-GGZZI: 0.0
# 650. customerID_3428-MMGUB: 0.0
# 651. customerID_3428-XZMAZ: 0.0
# 652. customerID_3439-GVUSX: 0.0
# 653. customerID_3452-ABWRL: 0.0
# 654. customerID_3440-JPSCL: 0.0
# 655. customerID_3441-CGZJH: 0.0
# 656. customerID_3442-ZHHCC: 0.0
# 657. customerID_3445-HXXGF: 0.0
# 658. customerID_3446-QDSZF: 0.0
# 659. customerID_3450-WXOAT: 0.0
# 660. customerID_3451-VAWLI: 0.0
# 661. customerID_3486-NPGST: 0.0
# 662. customerID_3487-EARAT: 0.0
# 663. customerID_3488-PGMQJ: 0.0
# 664. customerID_3530-VWVGU: 0.0
# 665. customerID_3521-MNKLV: 0.0
# 666. customerID_3522-CDKHF: 0.0
# 667. customerID_3523-BRGUW: 0.0
# 668. customerID_3524-WQDSG: 0.0
# 669. customerID_3525-DVKFN: 0.0
# 670. customerID_3528-HFRIQ: 0.0
# 671. customerID_3530-CRZSB: 0.0
# 672. customerID_3533-UVMOM: 0.0
# 673. customerID_3520-FJGCV: 0.0
# 674. customerID_3536-IQCTX: 0.0
# 675. customerID_3537-HPKQT: 0.0
# 676. customerID_3537-RYBHH: 0.0
# 677. customerID_3538-WZPHD: 0.0
# 678. customerID_3540-RZJYU: 0.0
# 679. customerID_3541-ZNUHK: 0.0
# 680. customerID_3544-FBCAS: 0.0
# 681. customerID_3521-HTQTV: 0.0
# 682. customerID_3519-ZKXGG: 0.0
# 683. customerID_3489-HHPFY: 0.0
# 684. customerID_3506-OVLKD: 0.0
# 685. customerID_3489-VSFRD: 0.0
# 686. customerID_3494-JCHRQ: 0.0
# 687. customerID_3496-LFSZU: 0.0
# 688. customerID_3498-LZGQZ: 0.0
# 689. customerID_3500-NSDOA: 0.0
# 690. customerID_3500-RMZLT: 0.0
# 691. customerID_3503-TYDAY: 0.0
# 692. customerID_3507-GASNP: 0.0
# 693. customerID_3518-PZXZQ: 0.0
# 694. customerID_3508-CFVZL: 0.0
# 695. customerID_3508-VLHCZ: 0.0
# 696. customerID_3509-GWQGF: 0.0
# 697. customerID_3511-APPBJ: 0.0
# 698. customerID_3511-BFTJW: 0.0
# 699. customerID_3512-IZIKN: 0.0
# 700. customerID_3518-FSTWG: 0.0
# 701. customerID_3422-LYEPQ: 0.0
# 702. customerID_3420-ZDBMA: 0.0
# 703. customerID_3292-PBZEJ: 0.0
# 704. customerID_3420-YJLQT: 0.0
# 705. customerID_3327-YBAKM: 0.0
# 706. customerID_3329-WDIOK: 0.0
# 707. customerID_3331-HQDTW: 0.0
# 708. customerID_3334-CTHOL: 0.0
# 709. customerID_3336-JORSO: 0.0
# 710. customerID_3339-EAQNV: 0.0
# 711. customerID_3340-QBBFM: 0.0
# 712. customerID_3345-JHUEO: 0.0
# 713. customerID_3345-PBBFH: 0.0
# 714. customerID_3346-BRMIS: 0.0
# 715. customerID_3347-YJZZE: 0.0
# 716. customerID_3348-CFRNX: 0.0
# 717. customerID_3349-ANQNH: 0.0
# 718. customerID_3351-NGXYI: 0.0
# 719. customerID_3352-ALMCK: 0.0
# 720. customerID_3352-RICWQ: 0.0
# 721. customerID_3354-OADJP: 0.0
# 722. customerID_3325-FUYCG: 0.0
# 723. customerID_3324-OIRTO: 0.0
# 724. customerID_3323-CPBWR: 0.0
# 725. customerID_3308-JSGML: 0.0
# 726. customerID_3295-YVUSR: 0.0
# 727. customerID_3296-SILRA: 0.0
# 728. customerID_3298-QEICA: 0.0
# 729. customerID_3301-LSLWQ: 0.0
# 730. customerID_3301-VKTGC: 0.0
# 731. customerID_3307-TLCUD: 0.0
# 732. customerID_3308-DGHKL: 0.0
# 733. customerID_3308-MHOOC: 0.0
# 734. customerID_3319-DWOEP: 0.0
# 735. customerID_3312-ZWLGF: 0.0
# 736. customerID_3315-IKYZQ: 0.0
# 737. customerID_3316-UWXUY: 0.0
# 738. customerID_3317-HRTNN: 0.0
# 739. customerID_3317-VLGQT: 0.0
# 740. customerID_3318-ISQFQ: 0.0
# 741. customerID_3318-NMQXL: 0.0
# 742. customerID_3359-DSRKA: 0.0
# 743. customerID_3363-DTIVD: 0.0
# 744. customerID_3363-EWLGO: 0.0
# 745. customerID_3410-MHHUM: 0.0
# 746. customerID_3398-GCPMU: 0.0
# 747. customerID_3398-ZOUAA: 0.0
# 748. customerID_3399-BMLVW: 0.0
# 749. customerID_3401-URHDA: 0.0
# 750. customerID_3402-XRIUO: 0.0
# 751. customerID_3407-JMJQQ: 0.0
# 752. customerID_3407-QGWLG: 0.0
# 753. customerID_3410-YOQBQ: 0.0
# 754. customerID_3397-AVTKU: 0.0
# 755. customerID_3411-WLRSQ: 0.0
# 756. customerID_3413-BMNZE: 0.0
# 757. customerID_3413-CSSTH: 0.0
# 758. customerID_3413-DHLPB: 0.0
# 759. customerID_3415-TAILE: 0.0
# 760. customerID_3417-TSCIC: 0.0
# 761. customerID_3419-SNJJD: 0.0
# 762. customerID_3398-FSHON: 0.0
# 763. customerID_3396-DKDEL: 0.0
# 764. customerID_3365-SAIGS: 0.0
# 765. customerID_3374-TTZTK: 0.0
# 766. customerID_3370-GQEAL: 0.0
# 767. customerID_3372-CDXFJ: 0.0
# 768. customerID_3372-KWFBM: 0.0
# 769. customerID_3373-DIUUN: 0.0
# 770. customerID_3373-YZZYM: 0.0
# 771. customerID_3374-LXDEV: 0.0
# 772. customerID_3374-PZLXD: 0.0
# 773. customerID_3376-BMGFE: 0.0
# 774. customerID_3393-FMZPV: 0.0
# 775. customerID_3378-AJRAO: 0.0
# 776. customerID_3387-PLKUI: 0.0
# 777. customerID_3387-VATUS: 0.0
# 778. customerID_3389-KTRXV: 0.0
# 779. customerID_3389-YGYAI: 0.0
# 780. customerID_3391-JSQEW: 0.0
# 781. customerID_3217-FZDMN: 0.0
# 782. customerID_3219-JQRSL: 0.0
# 783. PhoneService_Yes: 0.0
# 784. customerID_3214-IYUUQ: 0.0
# 785. customerID_2866-IKBTM: 0.0
# 786. customerID_2832-SCUCO: 0.0
# 787. customerID_2833-SLKDQ: 0.0
# 788. customerID_2834-JKOOW: 0.0
# 789. customerID_2834-SPCJV: 0.0
# 790. customerID_2840-XANRC: 0.0
# 791. customerID_2842-BCQGE: 0.0
# 792. customerID_2842-JTCCU: 0.0
# 793. customerID_2843-CQMEG: 0.0
# 794. customerID_2845-AFFTX: 0.0
# 795. customerID_2845-HSJCY: 0.0
# 796. customerID_2845-KDHVX: 0.0
# 797. customerID_2848-YXSMW: 0.0
# 798. customerID_2851-MMUTZ: 0.0
# 799. customerID_2851-STERV: 0.0
# 800. customerID_2853-CWQFQ: 0.0
# 801. customerID_2856-HYAPG: 0.0
# 802. customerID_2858-EIMXH: 0.0
# 803. customerID_2860-RANUS: 0.0
# 804. customerID_2862-JVEOY: 0.0
# 805. customerID_2862-PFNIK: 0.0
# 806. customerID_2863-IMQDR: 0.0
# 807. customerID_2832-KJCRD: 0.0
# 808. customerID_2830-LEWOA: 0.0
# 809. customerID_2829-HYVZP: 0.0
# 810. customerID_2812-SFXMJ: 0.0
# 811. customerID_2805-AUFQN: 0.0
# 812. customerID_2805-EDJPQ: 0.0
# 813. customerID_2806-MLNTI: 0.0
# 814. customerID_2808-CHTDM: 0.0
# 815. customerID_2809-ILCYT: 0.0
# 816. customerID_2809-ZMYOQ: 0.0
# 817. customerID_2811-POVEX: 0.0
# 818. customerID_2812-ENYMO: 0.0
# 819. customerID_2812-REYAT: 0.0
# 820. customerID_2815-CPTUL: 0.0
# 821. customerID_2828-SLQPF: 0.0
# 822. customerID_2817-LVCPP: 0.0
# 823. customerID_2817-NTQDO: 0.0
# 824. customerID_2819-GWENI: 0.0
# 825. customerID_2821-WARNZ: 0.0
# 826. customerID_2823-LKABH: 0.0
# 827. customerID_2824-DXNKN: 0.0
# 828. customerID_2824-MYYBN: 0.0
# 829. customerID_2826-DXLQO: 0.0
# 830. customerID_2826-UWHIS: 0.0
# 831. customerID_2865-TCHJW: 0.0
# 832. customerID_2867-UIMSS: 0.0
# 833. customerID_2801-NISEI: 0.0
# 834. customerID_2868-LLSKM: 0.0
# 835. customerID_2903-YYTBW: 0.0
# 836. customerID_2904-GGUAZ: 0.0
# 837. customerID_2907-ILJBN: 0.0
# 838. customerID_2908-WGAXL: 0.0
# 839. customerID_2908-ZTPNF: 0.0
# 840. customerID_2911-IJORQ: 0.0
# 841. customerID_2911-UREFD: 0.0
# 842. customerID_2911-WDXMV: 0.0
# 843. customerID_2919-HBCJO: 0.0
# 844. customerID_2921-XWDJH: 0.0
# 845. customerID_2924-KHUVI: 0.0
# 846. customerID_2925-MXLSX: 0.0
# 847. customerID_2925-VDZHY: 0.0
# 848. customerID_2926-JEJJC: 0.0
# 849. customerID_2927-CVULT: 0.0
# 850. customerID_2927-QRRQV: 0.0
# 851. customerID_2928-HLDBA: 0.0
# 852. customerID_2929-ERCFZ: 0.0
# 853. customerID_2930-UOTMB: 0.0
# 854. customerID_2931-FSOHN: 0.0
# 855. customerID_2931-SVLTV: 0.0
# 856. customerID_2900-PHPLN: 0.0
# 857. customerID_2898-MRKPI: 0.0
# 858. customerID_2897-DOVND: 0.0
# 859. customerID_2882-DDZPG: 0.0
# 860. customerID_2868-MZAGQ: 0.0
# 861. customerID_2868-SNELZ: 0.0
# 862. customerID_2873-ZLIWT: 0.0
# 863. customerID_2874-YXVVA: 0.0
# 864. customerID_2876-VBBBL: 0.0
# 865. customerID_2877-VDUER: 0.0
# 866. customerID_2878-DHMIN: 0.0
# 867. customerID_2878-RMWXY: 0.0
# 868. customerID_2880-FPNAE: 0.0
# 869. customerID_2882-WDTBA: 0.0
# 870. customerID_2896-TBNBE: 0.0
# 871. customerID_2883-ILGWO: 0.0
# 872. customerID_2884-GBPFB: 0.0
# 873. customerID_2885-HIJDH: 0.0
# 874. customerID_2886-KEFUM: 0.0
# 875. customerID_2887-JPYLU: 0.0
# 876. customerID_2888-ADFAO: 0.0
# 877. customerID_2890-WFBHU: 0.0
# 878. customerID_2892-GESUL: 0.0
# 879. customerID_2894-QOJRX: 0.0
# 880. customerID_2804-ETQDK: 0.0
# 881. customerID_2800-VEQXM: 0.0
# 882. customerID_3212-KXOCR: 0.0
# 883. customerID_2718-GAXQD: 0.0
# 884. customerID_2683-BPJSO: 0.0
# 885. customerID_2683-JXWQQ: 0.0
# 886. customerID_2684-EIWEO: 0.0
# 887. customerID_2685-SREOM: 0.0
# 888. customerID_2690-DVRVK: 0.0
# 889. customerID_2691-NZETQ: 0.0
# 890. customerID_2692-AQCPF: 0.0
# 891. customerID_2692-BUCFV: 0.0
# 892. customerID_2692-PFYTJ: 0.0
# 893. customerID_2694-CIUMO: 0.0
# 894. customerID_2696-ECXKC: 0.0
# 895. customerID_2696-NARTR: 0.0
# 896. customerID_2696-RZVZW: 0.0
# 897. customerID_2697-NQBPF: 0.0
# 898. customerID_2700-LUEVA: 0.0
# 899. customerID_2703-AMTUL: 0.0
# 900. customerID_2706-QZIHY: 0.0
# 901. customerID_2709-UQGNP: 0.0
# 902. customerID_2710-WYVXG: 0.0
# 903. customerID_2712-SYWAY: 0.0
# 904. customerID_2716-GFZOR: 0.0
# 905. customerID_2682-KEVRP: 0.0
# 906. customerID_2680-XKKNJ: 0.0
# 907. customerID_2676-SSLTO: 0.0
# 908. customerID_2672-HUYVI: 0.0
# 909. customerID_2660-EMUBI: 0.0
# 910. customerID_2661-GKBTK: 0.0
# 911. customerID_2662-NNTDK: 0.0
# 912. customerID_2664-XJZNO: 0.0
# 913. customerID_2665-NPTGL: 0.0
# 914. customerID_2668-TZSPS: 0.0
# 915. customerID_2669-OIDSD: 0.0
# 916. customerID_2669-QVCRG: 0.0
# 917. customerID_2672-DZUOY: 0.0
# 918. customerID_2672-OJQZP: 0.0
# 919. customerID_2676-OXPPQ: 0.0
# 920. customerID_2672-TGEFF: 0.0
# 921. customerID_2673-CXQEU: 0.0
# 922. customerID_2673-ZALNP: 0.0
# 923. customerID_2674-MIAHT: 0.0
# 924. customerID_2674-MLXMN: 0.0
# 925. customerID_2675-DHUTR: 0.0
# 926. customerID_2675-IJRGJ: 0.0
# 927. customerID_2675-OTVVJ: 0.0
# 928. customerID_2676-ISHSF: 0.0
# 929. customerID_2717-HVIZY: 0.0
# 930. customerID_2718-YSKCS: 0.0
# 931. customerID_2800-QQUSO: 0.0
# 932. customerID_2719-BDAQO: 0.0
# 933. customerID_2761-XECQW: 0.0
# 934. customerID_2770-NSVDG: 0.0
# 935. customerID_2773-MADBQ: 0.0
# 936. customerID_2773-OVBPK: 0.0
# 937. customerID_2774-LVQUS: 0.0
# 938. customerID_2777-PHDEI: 0.0
# 939. customerID_2778-OCLGR: 0.0
# 940. customerID_2782-JEEBU: 0.0
# 941. customerID_2782-LFZVW: 0.0
# 942. customerID_2786-GCDPI: 0.0
# 943. customerID_2788-CJQAQ: 0.0
# 944. customerID_2789-CZANW: 0.0
# 945. customerID_2790-XUYMV: 0.0
# 946. customerID_2791-SFVEW: 0.0
# 947. customerID_2792-LSHWX: 0.0
# 948. customerID_2792-VPPET: 0.0
# 949. customerID_2796-NNUFI: 0.0
# 950. customerID_2796-UUZZO: 0.0
# 951. customerID_2798-NYLMZ: 0.0
# 952. customerID_2799-ARNLO: 0.0
# 953. customerID_2799-TSLAG: 0.0
# 954. customerID_2758-RNWXS: 0.0
# 955. customerID_2754-XBHTB: 0.0
# 956. customerID_2754-VDLTR: 0.0
# 957. customerID_2731-GJRDG: 0.0
# 958. customerID_2720-FVBQP: 0.0
# 959. customerID_2720-WGKHP: 0.0
# 960. customerID_2722-JMONI: 0.0
# 961. customerID_2722-VOJQL: 0.0
# 962. customerID_2724-FJDYW: 0.0
# 963. customerID_2725-IWWBA: 0.0
# 964. customerID_2725-KXXWT: 0.0
# 965. customerID_2725-TTRIQ: 0.0
# 966. customerID_2729-VNVAP: 0.0
# 967. customerID_2732-ISEZX: 0.0
# 968. customerID_2753-JMMCV: 0.0
# 969. customerID_2737-WFVYW: 0.0
# 970. customerID_2737-YNGYW: 0.0
# 971. customerID_2739-CACDQ: 0.0
# 972. customerID_2739-CCZMB: 0.0
# 973. customerID_2740-JFBOK: 0.0
# 974. customerID_2746-DIJLO: 0.0
# 975. customerID_2748-MYRVK: 0.0
# 976. customerID_2749-CTKAJ: 0.0
# 977. customerID_2750-BJLSB: 0.0
# 978. customerID_2931-VUVJN: 0.0
# 979. customerID_2931-XIQBR: 0.0
# 980. customerID_2933-FILNV: 0.0
# 981. customerID_3146-MSEGF: 0.0
# 982. customerID_3106-ULWFW: 0.0
# 983. customerID_3108-PCCGG: 0.0
# 984. customerID_3113-IWHLC: 0.0
# 985. customerID_3115-JPJDD: 0.0
# 986. customerID_3118-UHVVQ: 0.0
# 987. customerID_3120-FAZKD: 0.0
# 988. customerID_3125-RAHBV: 0.0
# 989. customerID_3126-WQMGH: 0.0
# 990. customerID_3128-YOVTD: 0.0
# 991. customerID_3129-AAQOU: 0.0
# 992. customerID_3130-ICDUP: 0.0
# 993. customerID_3131-NWVFJ: 0.0
# 994. customerID_3133-PZNSR: 0.0
# 995. customerID_3134-DSHVC: 0.0
# 996. customerID_3137-LUPIX: 0.0
# 997. customerID_3137-NYQQI: 0.0
# 998. customerID_3138-BKYAV: 0.0
# 999. customerID_3143-ILDAL: 0.0
# 1000. customerID_3143-JQEGI: 0.0
# 1001. customerID_3144-AUDBS: 0.0
# 1002. customerID_3144-KMTWZ: 0.0
# 1003. customerID_3099-OONVS: 0.0
# 1004. customerID_3097-PYWXL: 0.0
# 1005. customerID_3097-NQYSN: 0.0
# 1006. customerID_3090-LETTY: 0.0
# 1007. customerID_3079-BCHLN: 0.0
# 1008. customerID_3082-VQXNH: 0.0
# 1009. customerID_3082-WQRVY: 0.0
# 1010. customerID_3082-YVEKW: 0.0
# 1011. customerID_3084-DOWLE: 0.0
# 1012. customerID_3086-RUCRN: 0.0
# 1013. customerID_3088-FVYWK: 0.0
# 1014. customerID_3088-LHEFH: 0.0
# 1015. customerID_3547-LQRIK: 0.0
# 1016. customerID_3090-QFUVD: 0.0
# 1017. customerID_3097-NNSPB: 0.0
# 1018. customerID_3091-FYHKI: 0.0
# 1019. customerID_3094-JOJAI: 0.0
# 1020. customerID_3096-GKWEB: 0.0
# 1021. customerID_3096-IZETN: 0.0
# 1022. customerID_3096-JRDSO: 0.0
# 1023. customerID_3096-WPXBT: 0.0
# 1024. customerID_3096-YXENJ: 0.0
# 1025. customerID_3097-FQTVJ: 0.0
# 1026. customerID_3097-IDVPU: 0.0
# 1027. customerID_3146-JTQHR: 0.0
# 1028. customerID_3148-AOIQT: 0.0
# 1029. customerID_2933-XEUJM: 0.0
# 1030. customerID_3154-CFSZG: 0.0
# 1031. customerID_3181-VTHOE: 0.0
# 1032. customerID_3186-AJIEK: 0.0
# 1033. customerID_3186-BAXNB: 0.0
# 1034. customerID_3190-FZATL: 0.0
# 1035. customerID_3190-ITQXP: 0.0
# 1036. customerID_3190-XFANI: 0.0
# 1037. customerID_3191-CSNMG: 0.0
# 1038. customerID_3192-LNKRK: 0.0
# 1039. customerID_3195-TQDZX: 0.0
# 1040. customerID_3196-NVXLZ: 0.0
# 1041. customerID_3197-ARFOY: 0.0
# 1042. customerID_3197-NNYNB: 0.0
# 1043. customerID_3198-VELRD: 0.0
# 1044. customerID_3199-NPKCN: 0.0
# 1045. customerID_3199-XGZCY: 0.0
# 1046. customerID_3200-MNQTF: 0.0
# 1047. customerID_3205-MXZRA: 0.0
# 1048. customerID_3207-OYBWH: 0.0
# 1049. customerID_3208-YPIOE: 0.0
# 1050. customerID_3209-ZPKFI: 0.0
# 1051. customerID_3211-AAPKX: 0.0
# 1052. customerID_3181-MIZBN: 0.0
# 1053. customerID_3179-GBRWV: 0.0
# 1054. customerID_3178-FESZO: 0.0
# 1055. customerID_3164-YAXFY: 0.0
# 1056. customerID_3154-HMWUU: 0.0
# 1057. customerID_3156-QLHBO: 0.0
# 1058. customerID_3158-MOERK: 0.0
# 1059. customerID_3160-TYXLT: 0.0
# 1060. customerID_3161-GETRM: 0.0
# 1061. customerID_3161-ONRWK: 0.0
# 1062. customerID_3162-KKZXO: 0.0
# 1063. customerID_3162-ZJZFU: 0.0
# 1064. customerID_3164-AALRN: 0.0
# 1065. customerID_3165-HDOEW: 0.0
# 1066. customerID_3178-CIFOT: 0.0
# 1067. customerID_3166-PNEOF: 0.0
# 1068. customerID_3167-SNQPL: 0.0
# 1069. customerID_3170-GWYKC: 0.0
# 1070. customerID_3170-NMYVV: 0.0
# 1071. customerID_3173-NVMPX: 0.0
# 1072. customerID_3173-WSSUE: 0.0
# 1073. customerID_3174-AKMAS: 0.0
# 1074. customerID_3174-RKMOW: 0.0
# 1075. customerID_3177-LASXD: 0.0
# 1076. customerID_3078-ZKNTS: 0.0
# 1077. customerID_3077-RSNTJ: 0.0
# 1078. customerID_3074-GQWYX: 0.0
# 1079. customerID_3071-VBYPO: 0.0
# 1080. customerID_2977-CEBSX: 0.0
# 1081. customerID_2978-XXSOG: 0.0
# 1082. customerID_2979-SXESE: 0.0
# 1083. customerID_2982-IHMFT: 0.0
# 1084. customerID_2982-VPSGI: 0.0
# 1085. customerID_2983-ZANRP: 0.0
# 1086. customerID_2984-AFWNC: 0.0
# 1087. customerID_2984-MIIZL: 0.0
# 1088. customerID_2984-RGEYA: 0.0
# 1089. customerID_2984-TBYKU: 0.0
# 1090. customerID_2985-FMWYF: 0.0
# 1091. customerID_2985-JUUBZ: 0.0
# 1092. customerID_2987-BJXIK: 0.0
# 1093. customerID_2988-GBIVW: 0.0
# 1094. customerID_2988-PLAHS: 0.0
# 1095. customerID_2988-QRAJY: 0.0
# 1096. customerID_2990-HWIML: 0.0
# 1097. customerID_2990-IAJSV: 0.0
# 1098. customerID_2990-OGYTD: 0.0
# 1099. customerID_2995-YWTCD: 0.0
# 1100. customerID_2996-XAUVF: 0.0
# 1101. customerID_2974-GGUXS: 0.0
# 1102. customerID_2972-YDYUW: 0.0
# 1103. customerID_2969-WGHQO: 0.0
# 1104. customerID_2957-LOLHO: 0.0
# 1105. customerID_2937-FTHUR: 0.0
# 1106. customerID_2946-KIQSP: 0.0
# 1107. customerID_2951-QOQTK: 0.0
# 1108. customerID_2952-QAYZF: 0.0
# 1109. customerID_2954-PIBKO: 0.0
# 1110. customerID_2955-BJZHG: 0.0
# 1111. customerID_2955-PSXOE: 0.0
# 1112. customerID_2956-GGUCQ: 0.0
# 1113. customerID_2957-JIRMN: 0.0
# 1114. customerID_2958-NHPPS: 0.0
# 1115. customerID_2969-VAPYH: 0.0
# 1116. customerID_2959-EEXWB: 0.0
# 1117. customerID_2959-FENLU: 0.0
# 1118. customerID_2959-MJHIC: 0.0
# 1119. customerID_2960-NKRSO: 0.0
# 1120. customerID_2961-VNFKL: 0.0
# 1121. customerID_2962-XPMCQ: 0.0
# 1122. customerID_2967-MXRAV: 0.0
# 1123. customerID_2968-SSGAA: 0.0
# 1124. customerID_2969-QWUBZ: 0.0
# 1125. customerID_2999-AANRQ: 0.0
# 1126. customerID_3001-CBHLQ: 0.0
# 1127. customerID_3001-UNBTL: 0.0
# 1128. customerID_3059-NGMXB: 0.0
# 1129. customerID_3049-SOLAY: 0.0
# 1130. customerID_3050-GBUSH: 0.0
# 1131. customerID_3050-RLLXC: 0.0
# 1132. customerID_3055-MJDSB: 0.0
# 1133. customerID_3055-OYMSE: 0.0
# 1134. customerID_3055-VTCGS: 0.0
# 1135. customerID_3057-VJJQE: 0.0
# 1136. customerID_3058-HJCUY: 0.0
# 1137. customerID_3058-WQDRE: 0.0
# 1138. customerID_3061-BCKYI: 0.0
# 1139. customerID_3045-XETSH: 0.0
# 1140. customerID_3062-ICYZQ: 0.0
# 1141. customerID_3066-RRJIO: 0.0
# 1142. customerID_3067-SVMTC: 0.0
# 1143. customerID_3068-OMWZA: 0.0
# 1144. customerID_3069-SSVSN: 0.0
# 1145. customerID_3070-BDOQC: 0.0
# 1146. customerID_3070-DVEYC: 0.0
# 1147. customerID_3070-FNFZQ: 0.0
# 1148. customerID_3071-MVJCD: 0.0
# 1149. customerID_3049-NDXFL: 0.0
# 1150. customerID_3043-TYBNO: 0.0
# 1151. customerID_3002-WQZWT: 0.0
# 1152. customerID_3018-TFTSU: 0.0
# 1153. customerID_3003-CMDUU: 0.0
# 1154. customerID_3005-NFMTA: 0.0
# 1155. customerID_3005-TYFRD: 0.0
# 1156. customerID_3006-XIMLN: 0.0
# 1157. customerID_3007-FDPEA: 0.0
# 1158. customerID_3011-WQKSZ: 0.0
# 1159. customerID_3012-VFFMN: 0.0
# 1160. customerID_3014-WJKSM: 0.0
# 1161. customerID_3016-KSVCP: 0.0
# 1162. customerID_3021-VLNRJ: 0.0
# 1163. customerID_3043-SUDUA: 0.0
# 1164. customerID_3022-BEXHZ: 0.0
# 1165. customerID_3023-GFLBR: 0.0
# 1166. customerID_3026-ATZYV: 0.0
# 1167. customerID_3027-YNWZU: 0.0
# 1168. customerID_3027-ZTDHO: 0.0
# 1169. customerID_3030-YDNRM: 0.0
# 1170. customerID_3030-ZKIWL: 0.0
# 1171. customerID_3038-PQIUY: 0.0
# 1172. customerID_3039-MJSLN: 0.0
# 1173. customerID_3546-GHEAE: 0.0
# 1174. customerID_3717-OEAUQ: 0.0
# 1175. customerID_3549-ZTMNH: 0.0
# 1176. customerID_4429-WYGFR: 0.0
# 1177. customerID_4412-YLTKF: 0.0
# ...
# 6594. customerID_7054-LGEQW: 0.0
# 6595. customerID_7055-HNEOJ: 0.0
# 6596. customerID_7055-JCGNI: 0.0
# 6597. customerID_7055-VKGDA: 0.0
# 6598. customerID_7056-IMHCC: 0.0
# 6599. customerID_7061-OVMIM: 0.0
# 6600. customerID_7064-FRRSW: 0.0
# 6601. customerID_7107-UBYKY: 0.0
# 6602. customerID_7109-CQYUZ: 0.0
# 6603. customerID_7184-LRUUR: 0.0
# 6604. customerID_7109-MFBYV: 0.0
# 6605. customerID_7147-AYBAA: 0.0
# 6606. customerID_7148-XZPHA: 0.0
# 6607. customerID_7153-CHRBV: 0.0
# 6608. customerID_7153-OANIO: 0.0
# 6609. customerID_7156-MHUGY: 0.0
# 6610. customerID_7156-MXBJE: 0.0
# 6611. customerID_7157-SMCFK: 0.0
# 6612. customerID_7159-FVYPK: 0.0
# 6613. customerID_7159-NOKYQ: 0.0
# 6614. customerID_7161-DFHUF: 0.0
# 6615. customerID_7162-WPHPM: 0.0
# 6616. customerID_7163-OCEQI: 0.0
# 6617. customerID_7164-BPTUT: 0.0
# 6618. customerID_7167-PCEYD: 0.0
# 6619. customerID_7168-HDQHG: 0.0
# 6620. customerID_7169-YWAMK: 0.0
# 6621. customerID_7173-TETGO: 0.0
# 6622. customerID_7175-NTIXE: 0.0
# 6623. customerID_7176-WRTNX: 0.0
# 6624. customerID_7180-PISOG: 0.0
# 6625. customerID_7181-BQYBV: 0.0
# 6626. customerID_7181-OQCUT: 0.0
# 6627. customerID_7182-OVLBJ: 0.0
# 6628. customerID_7143-BQIBA: 0.0
# 6629. customerID_7142-HVGBG: 0.0
# 6630. customerID_7140-ADSMJ: 0.0
# 6631. customerID_7129-AZJDE: 0.0
# 6632. customerID_7110-BDTWG: 0.0
# 6633. customerID_7112-OPOTK: 0.0
# 6634. customerID_7113-HIPFI: 0.0
# 6635. customerID_7114-AEOZE: 0.0
# 6636. customerID_7115-IRDHS: 0.0
# 6637. customerID_7120-RFMVS: 0.0
# 6638. customerID_7123-WQUHX: 0.0
# 6639. customerID_7126-RBHSD: 0.0
# 6640. customerID_7128-GGCNO: 0.0
# 6641. customerID_7129-ACFOG: 0.0
# 6642. customerID_7129-CAKJW: 0.0
# 6643. customerID_7139-JZFVG: 0.0
# 6644. customerID_7130-CTCUS: 0.0
# 6645. customerID_7130-VTEWQ: 0.0
# 6646. customerID_7130-YXBRO: 0.0
# 6647. customerID_7131-ZQZNK: 0.0
# 6648. customerID_7134-HBPBS: 0.0
# 6649. customerID_7134-MJPDY: 0.0
# 6650. customerID_7136-IHZJA: 0.0
# 6651. customerID_7137-NAXML: 0.0
# 6652. customerID_7137-RYLPP: 0.0
# 6653. customerID_7138-GIRSH: 0.0
# 6654. customerID_6711-VTNRE: 0.0
# 6655. customerID_6711-FLDFB: 0.0
# 6656. customerID_6710-HSJRD: 0.0
# 6657. customerID_6322-HRPFA: 0.0
# 6658. customerID_6283-GITPX: 0.0
# 6659. customerID_6284-KMNUF: 0.0
# 6660. customerID_6285-FTQBF: 0.0
# 6661. customerID_6286-SUUWT: 0.0
# 6662. customerID_6286-ZHAOK: 0.0
# 6663. customerID_6288-CHQJB: 0.0
# 6664. customerID_6288-LBEAR: 0.0
# 6665. customerID_6289-CPNLD: 0.0
# 6666. customerID_6292-TOSSS: 0.0
# 6667. customerID_6295-OSINB: 0.0
# 6668. customerID_6296-DDOOR: 0.0
# 6669. customerID_6297-NOOPG: 0.0
# 6670. customerID_6298-QDFNH: 0.0
# 6671. customerID_6300-BWMJX: 0.0
# 6672. customerID_6302-JGYRJ: 0.0
# 6673. customerID_6303-KFWSL: 0.0
# 6674. customerID_6304-IJFSQ: 0.0
# 6675. customerID_6305-YLBMM: 0.0
# 6676. customerID_6308-CQRBU: 0.0
# 6677. customerID_6311-UEUME: 0.0
# 6678. customerID_6313-GIDIT: 0.0
# 6679. customerID_6317-YPKDH: 0.0
# 6680. customerID_6319-IEJWJ: 0.0
# 6681. customerID_6281-FKEWS: 0.0
# 6682. customerID_6278-FEPBZ: 0.0
# 6683. customerID_6275-YDUVO: 0.0
# 6684. customerID_6253-WRFHY: 0.0
# 6685. customerID_6242-FEGFD: 0.0
# 6686. customerID_6242-MBHPK: 0.0
# 6687. customerID_6242-SGYTS: 0.0
# 6688. customerID_6243-OZGFH: 0.0
# 6689. customerID_6244-BESBM: 0.0
# 6690. customerID_6248-BSHKG: 0.0
# 6691. customerID_6248-TKCQV: 0.0
# 6692. customerID_6250-CGGUN: 0.0
# 6693. customerID_6252-DFGTK: 0.0
# 6694. customerID_6253-GNHWH: 0.0
# 6695. customerID_6257-DTAYD: 0.0
# 6696. customerID_6267-DCFFZ: 0.0
# 6697. customerID_6257-RJOHI: 0.0
# 6698. customerID_6258-NGCNG: 0.0
# 6699. customerID_6258-PVZWJ: 0.0
# 6700. customerID_6259-WJQLC: 0.0
# 6701. customerID_6260-ONULR: 0.0
# 6702. customerID_6260-XLACS: 0.0
# 6703. customerID_6261-LHRTG: 0.0
# 6704. customerID_6265-FRMTQ: 0.0
# 6705. customerID_6265-SXWBU: 0.0
# 6706. customerID_6266-QHOJZ: 0.0
# 6707. customerID_6319-QSUSR: 0.0
# 6708. customerID_6322-PJJDJ: 0.0
# 6709. customerID_6234-RAAPL: 0.0
# 6710. customerID_6326-MTTXK: 0.0
# 6711. customerID_6360-SVNWV: 0.0
# 6712. customerID_6365-HITVU: 0.0
# 6713. customerID_6366-XIVKZ: 0.0
# 6714. customerID_6366-ZGQGL: 0.0
# 6715. customerID_6368-NWMCE: 0.0
# 6716. customerID_6368-TZZDT: 0.0
# 6717. customerID_6369-MCAKO: 0.0
# 6718. customerID_6370-ZVHDV: 0.0
# 6719. customerID_6371-NZYEG: 0.0
# 6720. customerID_6372-RFVNS: 0.0
# 6721. customerID_6374-AFWOX: 0.0
# 6722. customerID_6374-NTQLP: 0.0
# 6723. customerID_6376-GAHQE: 0.0
# 6724. customerID_6377-KSLXC: 0.0
# 6725. customerID_6377-WHAOX: 0.0
# 6726. customerID_6379-RXJRQ: 0.0
# 6727. customerID_6380-ARCEH: 0.0
# 6728. customerID_6383-ZTSIW: 0.0
# 6729. customerID_6384-VMJHP: 0.0
# 6730. customerID_6388-TABGU: 0.0
# 6731. customerID_6390-DSAZX: 0.0
# 6732. customerID_6393-WRYZE: 0.0
# 6733. customerID_6394-HHHZM: 0.0
# 6734. customerID_6358-LYNGM: 0.0
# 6735. customerID_6357-JJPQT: 0.0
# 6736. customerID_6356-ELRKD: 0.0
# 6737. customerID_6341-AEVKX: 0.0
# 6738. customerID_6328-ZPBGN: 0.0
# 6739. customerID_6330-JKLPC: 0.0
# 6740. customerID_6331-EWIEB: 0.0
# 6741. customerID_6331-LWDTQ: 0.0
# 6742. customerID_6332-FBZRI: 0.0
# 6743. customerID_6333-YDVLT: 0.0
# 6744. customerID_6339-DKLMK: 0.0
# 6745. customerID_6339-RZCBJ: 0.0
# 6746. customerID_6339-TBELP: 0.0
# 6747. customerID_6340-DACFT: 0.0
# 6748. customerID_6341-JVQGF: 0.0
# 6749. customerID_6353-BRMMA: 0.0
# 6750. customerID_6344-SFJVH: 0.0
# 6751. customerID_6345-FZOQH: 0.0
# 6752. customerID_6345-HOVES: 0.0
# 6753. customerID_6347-DCUIK: 0.0
# 6754. customerID_6348-SNFUS: 0.0
# 6755. customerID_6349-JDHQP: 0.0
# 6756. customerID_6350-XFYGW: 0.0
# 6757. customerID_6351-SCJKT: 0.0
# 6758. customerID_6352-GIGGQ: 0.0
# 6759. customerID_6352-TWCAU: 0.0
# 6760. customerID_6235-VDHOM: 0.0
# 6761. customerID_6234-PFPXL: 0.0
# 6762. customerID_6705-LXORM: 0.0
# 6763. customerID_6161-UUUTA: 0.0
# 6764. customerID_6127-ISGTU: 0.0
# 6765. customerID_6127-IYJOZ: 0.0
# 6766. customerID_6128-AQBMT: 0.0
# 6767. customerID_6128-CZOMY: 0.0
# 6768. customerID_6128-DAFVY: 0.0
# 6769. customerID_6131-FOYAS: 0.0
# 6770. customerID_6131-IUNXN: 0.0
# 6771. customerID_6131-JLWZM: 0.0
# 6772. customerID_6133-OZILE: 0.0
# 6773. customerID_6134-KWTBV: 0.0
# 6774. customerID_6135-OZQVA: 0.0
# 6775. customerID_6137-MFAJN: 0.0
# 6776. customerID_6137-NICCO: 0.0
# 6777. customerID_6139-ZZRBQ: 0.0
# 6778. customerID_6140-QNRQQ: 0.0
# 6779. customerID_6142-VSJQO: 0.0
# 6780. customerID_6143-JQKEA: 0.0
# 6781. customerID_6145-NNPNO: 0.0
# 6782. customerID_6147-CBCRA: 0.0
# 6783. customerID_6152-ONASV: 0.0
# 6784. customerID_6156-UZDLF: 0.0
# 6785. customerID_6158-DWPZT: 0.0
# 6786. customerID_6158-HDPXZ: 0.0
# 6787. customerID_6124-ACRHJ: 0.0
# 6788. customerID_6122-LJADA: 0.0
# 6789. customerID_6122-EFVKN: 0.0
# 6790. customerID_6100-QQHEB: 0.0
# 6791. customerID_6082-GLJIX: 0.0
# 6792. customerID_6082-OQFBA: 0.0
# 6793. customerID_6086-ESGRL: 0.0
# 6794. customerID_6087-MVHJH: 0.0
# 6795. customerID_6087-YPWHO: 0.0
# 6796. customerID_6088-BXMRG: 0.0
# 6797. customerID_6092-QZVPP: 0.0
# 6798. customerID_6094-ZIVKX: 0.0
# 6799. customerID_6096-EGVTU: 0.0
# 6800. customerID_6100-FJZDG: 0.0
# 6801. customerID_6101-IMRMM: 0.0
# 6802. customerID_6121-TNHBO: 0.0
# 6803. customerID_6103-LIANB: 0.0
# 6804. customerID_6103-QCKFX: 0.0
# 6805. customerID_6108-OQZDQ: 0.0
# 6806. customerID_6110-OHIHY: 0.0
# 6807. customerID_6112-KTHFQ: 0.0
# 6808. customerID_6114-TCFID: 0.0
# 6809. customerID_6115-ZTBFQ: 0.0
# 6810. customerID_6116-RFVHN: 0.0
# 6811. customerID_6119-SPUDB: 0.0
# 6812. customerID_6120-RJKLU: 0.0
# 6813. customerID_6161-ERDGD: 0.0
# 6814. customerID_6164-HAQTX: 0.0
# 6815. customerID_6233-HXJMX: 0.0
# 6816. customerID_6164-HXUGH: 0.0
# 6817. customerID_6199-IPCAO: 0.0
# 6818. customerID_6199-IWKGC: 0.0
# 6819. customerID_6202-DYYFX: 0.0
# 6820. customerID_6202-JVYEU: 0.0
# 6821. customerID_6203-HBZPA: 0.0
# 6822. customerID_6204-IEUXJ: 0.0
# 6823. customerID_6207-WIOLX: 0.0
# 6824. customerID_6210-KBBPI: 0.0
# 6825. customerID_6211-WHMYA: 0.0
# 6826. customerID_6211-WWLTF: 0.0
# 6827. customerID_6212-ATMLK: 0.0
# 6828. customerID_6215-NQCPY: 0.0
# 6829. customerID_6217-KDYWC: 0.0
# 6830. customerID_6217-TOWGS: 0.0
# 6831. customerID_6218-KNUBD: 0.0
# 6832. customerID_6221-AVQYL: 0.0
# 6833. customerID_6223-DHJGV: 0.0
# 6834. customerID_6227-FBDXH: 0.0
# 6835. customerID_6227-HWPWX: 0.0
# 6836. customerID_6229-LSCKB: 0.0
# 6837. customerID_6229-UOLQL: 0.0
# 6838. customerID_6230-BSUXY: 0.0
# 6839. customerID_6231-WFGFH: 0.0
# 6840. customerID_6198-ZFIOJ: 0.0
# 6841. customerID_6198-RTPMF: 0.0
# 6842. customerID_6198-PNNSZ: 0.0
# 6843. customerID_6174-NRBTZ: 0.0
# 6844. customerID_6166-ILMNY: 0.0
# 6845. customerID_6166-YIPFO: 0.0
# 6846. customerID_6168-WFVVF: 0.0
# 6847. customerID_6168-YBYNP: 0.0
# 6848. customerID_6169-PGNCD: 0.0
# 6849. customerID_6169-PPETC: 0.0
# 6850. customerID_6171-ZTVYB: 0.0
# 6851. customerID_6172-FECYY: 0.0
# 6852. customerID_6173-GOLSU: 0.0
# 6853. customerID_6173-ITPWD: 0.0
# 6854. customerID_6176-YJWAS: 0.0
# 6855. customerID_6196-HBOBZ: 0.0
# 6856. customerID_6177-PEVRA: 0.0
# 6857. customerID_6178-KFNHS: 0.0
# 6858. customerID_6179-GJPSO: 0.0
# 6859. customerID_6180-YBIQI: 0.0
# 6860. customerID_6181-AXXYF: 0.0
# 6861. customerID_6184-DYUOB: 0.0
# 6862. customerID_6185-TASNN: 0.0
# 6863. customerID_6188-UXBBR: 0.0
# 6864. customerID_6194-HBGQN: 0.0
# 6865. customerID_6195-MELTI: 0.0
# 6866. customerID_6394-MFYNG: 0.0
# 6867. customerID_6397-JNZZG: 0.0
# 6868. customerID_6400-BWQKW: 0.0
# 6869. customerID_6633-SYEUS: 0.0
# 6870. customerID_6609-MXJHJ: 0.0
# 6871. customerID_6614-FHDBO: 0.0
# 6872. customerID_6614-VBEGU: 0.0
# 6873. customerID_6614-YOLAC: 0.0
# 6874. customerID_6614-YWYSC: 0.0
# 6875. customerID_6615-NGGZJ: 0.0
# 6876. customerID_6615-ZGEDR: 0.0
# 6877. customerID_6616-AALSR: 0.0
# 6878. customerID_6617-WLBQC: 0.0
# 6879. customerID_6618-RYATB: 0.0
# 6880. customerID_6619-RPLQZ: 0.0
# 6881. customerID_6620-HVDUJ: 0.0
# 6882. customerID_6620-JDYNW: 0.0
# 6883. customerID_6621-NRZAK: 0.0
# 6884. customerID_6621-YOBKI: 0.0
# 6885. customerID_6624-JDRDS: 0.0
# 6886. customerID_6625-FLENO: 0.0
# 6887. customerID_6625-IUTTT: 0.0
# 6888. customerID_6625-UTXEW: 0.0
# 6889. customerID_6627-CFOSN: 0.0
# 6890. customerID_6629-CZTTH: 0.0
# 6891. customerID_6629-LADHQ: 0.0
# 6892. customerID_6631-HMANX: 0.0
# 6893. customerID_6608-QQLVK: 0.0
# 6894. customerID_6603-YRDCJ: 0.0
# 6895. customerID_6603-QWSPR: 0.0
# 6896. customerID_6583-QGCSI: 0.0
# 6897. customerID_6572-ADKRS: 0.0
# 6898. customerID_6574-MCOEH: 0.0
# 6899. customerID_6575-SUVOI: 0.0
# 6900. customerID_6576-FBXOJ: 0.0
# 6901. customerID_6578-KRMAW: 0.0
# 6902. customerID_6579-JPICP: 0.0
# 6903. customerID_6581-NQCBA: 0.0
# 6904. customerID_6582-OIVSP: 0.0
# 6905. customerID_6582-PLFUU: 0.0
# 6906. customerID_6583-KQJLK: 0.0
# 6907. customerID_6583-SZVGP: 0.0
# 6908. customerID_6599-SFQVE: 0.0
# 6909. customerID_6584-VQMYT: 0.0
# 6910. customerID_6585-WCEWR: 0.0
# 6911. customerID_6586-MYGKD: 0.0
# 6912. customerID_6586-PSJOX: 0.0
# 6913. customerID_6591-QGOYB: 0.0
# 6914. customerID_6595-COKXZ: 0.0
# 6915. customerID_6595-YGXIT: 0.0
# 6916. customerID_6598-KELSS: 0.0
# 6917. customerID_6599-GZWCM: 0.0
# 6918. customerID_6599-RCLCJ: 0.0
# 6919. customerID_6633-MPWBS: 0.0
# 6920. customerID_6635-CPNUN: 0.0
# 6921. customerID_6402-EJMWF: 0.0
# 6922. customerID_6637-KYRCV: 0.0
# 6923. customerID_6682-VCIXC: 0.0
# 6924. customerID_6683-VLCTZ: 0.0
# 6925. customerID_6685-GBWJZ: 0.0
# 6926. customerID_6685-XSHHU: 0.0
# 6927. customerID_6686-YPGHK: 0.0
# 6928. customerID_6688-UZPWD: 0.0
# 6929. customerID_6689-KXGBO: 0.0
# 6930. customerID_6689-TCZHQ: 0.0
# 6931. customerID_6689-VRRTK: 0.0
# 6932. customerID_6691-CCIHA: 0.0
# 6933. customerID_6692-UDPJC: 0.0
# 6934. customerID_6692-YQHXC: 0.0
# 6935. customerID_6693-DJWTY: 0.0
# 6936. customerID_6693-FRIRW: 0.0
# 6937. customerID_6695-AMZUF: 0.0
# 6938. customerID_6695-FRVEC: 0.0
# 6939. customerID_6696-YDAYZ: 0.0
# 6940. customerID_6698-OXETB: 0.0
# 6941. customerID_6701-DHKWQ: 0.0
# 6942. customerID_6701-YVNQG: 0.0
# 6943. customerID_6702-OHFWR: 0.0
# 6944. customerID_6704-UTUKK: 0.0
# 6945. customerID_6705-LNMDD: 0.0
# 6946. customerID_6681-ZSEXG: 0.0
# 6947. customerID_6680-WKXRZ: 0.0
# 6948. customerID_6674-KVJHG: 0.0
# 6949. customerID_6652-YFFJO: 0.0
# 6950. customerID_6641-XRPSU: 0.0
# 6951. customerID_6645-MXQJT: 0.0
# 6952. customerID_6646-JPPHA: 0.0
# 6953. customerID_6646-VRFOL: 0.0
# 6954. customerID_6647-ZEDXT: 0.0
# 6955. customerID_6648-INWPS: 0.0
# 6956. customerID_6650-BWFRT: 0.0
# 6957. customerID_6650-VJONK: 0.0
# 6958. customerID_6651-AZVTJ: 0.0
# 6959. customerID_6651-RLGGM: 0.0
# 6960. customerID_6653-CBBOM: 0.0
# 6961. customerID_6671-NGWON: 0.0
# 6962. customerID_6654-QGBZZ: 0.0
# 6963. customerID_6655-LHBYW: 0.0
# 6964. customerID_6656-GULJQ: 0.0
# 6965. customerID_6656-JWRQX: 0.0
# 6966. customerID_6661-EIPZC: 0.0
# 6967. customerID_6661-HBGWL: 0.0
# 6968. customerID_6663-JOCQO: 0.0
# 6969. customerID_6664-FPDAC: 0.0
# 6970. customerID_6668-CNMFP: 0.0
# 6971. customerID_6670-MFRPK: 0.0
# 6972. customerID_6569-KTMDU: 0.0
# 6973. customerID_6568-POCUI: 0.0
# 6974. customerID_6567-HOOPW: 0.0
# 6975. customerID_6563-VRERX: 0.0
# 6976. customerID_6440-DKQGE: 0.0
# 6977. customerID_6445-TNRXS: 0.0
# 6978. customerID_6447-EGDIV: 0.0
# 6979. customerID_6447-GORXK: 0.0
# 6980. customerID_6457-GIRWB: 0.0
# 6981. customerID_6457-USBER: 0.0
# 6982. customerID_6458-CYIDZ: 0.0
# 6983. customerID_6461-PPAXN: 0.0
# 6984. customerID_6461-SZMCV: 0.0
# 6985. customerID_6463-HHXJR: 0.0
# 6986. customerID_6463-MVYRY: 0.0
# 6987. customerID_6464-KEXXH: 0.0
# 6988. customerID_6465-GSRCL: 0.0
# 6989. customerID_6467-CHFZW: 0.0
# 6990. customerID_6469-MRVET: 0.0
# 6991. customerID_6469-QJKZW: 0.0
# 6992. customerID_6473-ULUHT: 0.0
# 6993. customerID_6474-FVJLC: 0.0
# 6994. customerID_6475-VHUIZ: 0.0
# 6995. customerID_6476-EPYZR: 0.0
# 6996. customerID_6476-YHMGA: 0.0
# 6997. customerID_6478-HRRCZ: 0.0
# 6998. customerID_6479-OAUSD: 0.0
# 6999. customerID_6439-PKTRR: 0.0
# 7000. customerID_6439-LAJXL: 0.0
# 7001. customerID_6437-UKHMV: 0.0
# 7002. customerID_6416-YJTTB: 0.0
# 7003. customerID_6402-SSEJG: 0.0
# 7004. customerID_6402-ZFPPI: 0.0
# 7005. customerID_6407-GSJNL: 0.0
# 7006. customerID_6407-UTSLV: 0.0
# 7007. customerID_6408-OTUBZ: 0.0
# 7008. customerID_6408-WHTEF: 0.0
# 7009. customerID_6410-LEFEN: 0.0
# 7010. customerID_6413-XKKPU: 0.0
# 7011. customerID_6416-JNVRK: 0.0
# 7012. customerID_6416-TVAIH: 0.0
# 7013. customerID_6418-HNFED: 0.0
# 7014. customerID_6437-UDQJM: 0.0
# 7015. customerID_6418-PIQSP: 0.0
# 7016. customerID_6419-ZTTLE: 0.0
# 7017. customerID_6421-SZVEM: 0.0
# 7018. customerID_6424-ELEYH: 0.0
# 7019. customerID_6425-JWTDV: 0.0
# 7020. customerID_6427-FEFIG: 0.0
# 7021. customerID_6429-SHBCB: 0.0
# 7022. customerID_6432-TWQLB: 0.0
# 7023. customerID_6434-TTGJP: 0.0
# 7024. customerID_6435-VWCCY: 0.0
# 7025. customerID_6479-SZPLM: 0.0
# 7026. customerID_6479-VDGRK: 0.0
# 7027. customerID_6480-YAGIY: 0.0
# 7028. customerID_6543-JXSOO: 0.0
# 7029. customerID_6519-ZHPXP: 0.0
# 7030. customerID_6521-YYTYI: 0.0
# 7031. customerID_6522-OIQSX: 0.0
# 7032. customerID_6522-YRBXD: 0.0
# 7033. customerID_6527-PZFPV: 0.0
# 7034. customerID_6537-OTKMY: 0.0
# 7035. customerID_6537-QLGEX: 0.0
# 7036. customerID_6538-POCHL: 0.0
# 7037. customerID_6542-LWGXJ: 0.0
# 7038. customerID_6543-CPZMK: 0.0
# 7039. customerID_6543-XRMYR: 0.0
# 7040. customerID_6518-PPLMZ: 0.0
# 7041. customerID_6546-OPBBH: 0.0
# 7042. customerID_6549-BTYPG: 0.0
# 7043. customerID_6549-NNDYT: 0.0
# 7044. customerID_6549-YMFAW: 0.0
# 7045. customerID_6551-GNYDG: 0.0
# 7046. customerID_6551-VLJMV: 0.0
# 7047. customerID_6551-ZCOTS: 0.0
# 7048. customerID_6556-DBKZF: 0.0
# 7049. customerID_6559-PDZLR: 0.0
# 7050. customerID_6559-RAKOZ: 0.0
# 7051. customerID_6519-CFDBX: 0.0
# 7052. customerID_6518-LGAOV: 0.0
# 7053. customerID_6481-ESCNL: 0.0
# 7054. customerID_6502-KUGLL: 0.0
# 7055. customerID_6481-LXPWL: 0.0
# 7056. customerID_6483-OATDN: 0.0
# 7057. customerID_6484-LATFU: 0.0
# 7058. customerID_6485-QXWWE: 0.0
# 7059. customerID_6486-LHTMA: 0.0
# 7060. customerID_6490-FGZAT: 0.0
# 7061. customerID_6496-SLWHQ: 0.0
# 7062. customerID_6497-TILVL: 0.0
# 7063. customerID_6500-JVEGC: 0.0
# 7064. customerID_6502-HCJTI: 0.0
# 7065. customerID_6502-MJQAE: 0.0
# 7066. customerID_6518-KZXCB: 0.0
# 7067. customerID_6504-VBLFL: 0.0
# 7068. customerID_6505-OZNPG: 0.0
# 7069. customerID_6506-EYCNH: 0.0
# 7070. customerID_6507-DTJZV: 0.0
# 7071. customerID_6507-ZJSUR: 0.0
# 7072. customerID_6508-NJYRO: 0.0
# 7073. customerID_6509-TSGWN: 0.0
# 7074. customerID_6510-UPNKS: 0.0
# 7075. customerID_6513-EECDB: 0.0
# 7076. customerID_6516-NKQBO: 0.0
# 7077. customerID_5022-JNQEQ: 0.0

# %%
# Оптимизированная визуализация дерева решений
plt.figure(figsize=(15, 10))
plot_tree(dt, feature_names=X.columns, class_names=["Not Churn", "Churn"], filled=True, max_depth=3)
plt.show()

# %%
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.89      0.88       557
#          Yes       0.55      0.49      0.52       147
#
#     accuracy                           0.81       704
#    macro avg       0.71      0.69      0.70       704
# weighted avg       0.80      0.81      0.81       704

# %% [markdown]
# <img src='hugetree.png'>

# %% [markdown]
# ## Случайный лес (Random Forest)
#
# **Задание: Создайте модель случайного леса, затем выведите отчёт "classification report" и матрицу ошибок для предсказанных результатов на тестовом наборе данных.**

# %%
# Создание модели случайного леса
rf = RandomForestClassifier(n_estimators=100, random_state=101)
rf.fit(X_train, Y_train)

# Оценка метрик работы модели
Y_pred = rf.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#           No       0.86      0.91      0.89       557
#          Yes       0.57      0.46      0.51       147
#
#     accuracy                           0.82       704
#    macro avg       0.72      0.68      0.70       704
# weighted avg       0.80      0.82      0.81       704

# %%
# Визуализация матрицы ошибок
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["Not Churn", "Churn"], yticklabels=["Not Churn", "Churn"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
# Out:
# RandomForestClassifier()

# %%
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.89      0.87       557
#          Yes       0.52      0.44      0.48       147
#
#     accuracy                           0.80       704
#    macro avg       0.69      0.67      0.68       704
# weighted avg       0.79      0.80      0.79       704

# %% [markdown]
# ## Расширяемые деревья (Boosted Trees)
#
# **Задание: Создайте модель AdaBoost или Gradient Boosting, затем выведите отчёт "classification report" и матрицу ошибок для предсказанных результатов на тестовом наборе данных.**

# %%
# Напишите Ваш код в этой ячейке
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Создание модели AdaBoost
adaboost = AdaBoostClassifier(n_estimators=100, random_state=101)
adaboost.fit(X_train, Y_train)

# Оценка метрик работы модели AdaBoost
Y_pred_adaboost = adaboost.predict(X_test)
print("AdaBoost Classification Report:")
print(classification_report(Y_test, Y_pred_adaboost))

# Визуализация матрицы ошибок для модели AdaBoost
cm_adaboost = confusion_matrix(Y_test, Y_pred_adaboost)
sns.heatmap(cm_adaboost, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["Not Churn", "Churn"], yticklabels=["Not Churn", "Churn"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - AdaBoost")
plt.show()
# Out:
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# AdaBoost Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.88      0.91      0.90       557
#          Yes       0.62      0.53      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.75      0.72      0.73       704
# weighted avg       0.83      0.83      0.83       704

# %%
# Создание модели Gradient Boosting
gradient_boosting = GradientBoostingClassifier(n_estimators=100, random_state=101)
gradient_boosting.fit(X_train, Y_train)

# Оценка метрик работы модели Gradient Boosting
Y_pred_gradient_boosting = gradient_boosting.predict(X_test)
print("Gradient Boosting Classification Report:")
print(classification_report(Y_test, Y_pred_gradient_boosting))

# Визуализация матрицы ошибок для модели Gradient Boosting
cm_gradient_boosting = confusion_matrix(Y_test, Y_pred_gradient_boosting)
sns.heatmap(cm_gradient_boosting, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["Not Churn", "Churn"], yticklabels=["Not Churn", "Churn"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - Gradient Boosting")
plt.show()
# Out:
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# C:\Users\invet\anaconda3\lib\site-packages\sklearn\utils\validation.py:768: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.87      0.91      0.89       557
#          Yes       0.60      0.50      0.55       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.71      0.72       704
# weighted avg       0.82      0.83      0.82       704

# %%
# Out:
# AdaBoostClassifier()

# %%
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       557
#          Yes       0.60      0.54      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.72      0.73       704
# weighted avg       0.82      0.83      0.83       704

# %% [markdown]
# **Задания: Сравнивая результаты, какая модель у Вас работает лучше других?**

# %%
# Наилучшие результаты в модели AdaBoostClassifier, 
# однако надо сказать, что не выполнялся поиск по сетке grid search,
# и целом модели показывали очень похожие результаты на этих данных.
